# %%
from pathlib import Path
import numpy as np
import pandas as pd
import json
from collections import Counter


import imblearn

from time import time
from datetime import datetime, date

import string
from sklearn.preprocessing import LabelEncoder

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import to_categorical
from keras.preprocessing.text import Tokenizer, one_hot
from keras.preprocessing.sequence import pad_sequences
from keras import Sequential
from keras import layers

import matplotlib.pyplot as plt
import seaborn as sns

# define Path object for data directory
root_dir = Path('./')
data_dir = root_dir / 'data'
models_dir = root_dir / 'models'
plots_dir = root_dir / 'plots'

# print data files
for data_file in data_dir.glob('*'):
    print(data_file)
    
# create directory for plots and models
plots_dir.mkdir(exist_ok=True)
models_dir.mkdir(exist_ok=True)
# Out:
# data/train.json
# data/test_cleaned.csv
# data/train_cleaned.csv
# data/test.json
# data/twitter_train.csv

# %% [markdown]
# # Original dataset

# %%
train = pd.read_json(data_dir / 'train.json')#.drop('Unnamed: 0', axis=1)
test = pd.read_json(data_dir / 'test.json')

print(train.shape)
train.head(5)
# Out:
# (8263, 3)
#                                                 text    id sentiment
# 0  Досудебное расследование по факту покупки ЕНПФ...  1945  negative
# 1  Медики рассказали о состоянии пострадавшего му...  1957  negative
# 2  Прошел почти год, как железнодорожным оператор...  1969  negative
# 3  По итогам 12 месяцев 2016 года на территории р...  1973  negative
# 4  Астана. 21 ноября. Kazakhstan Today - Агентств...  1975  negative

# %%
# get the number of words in each sample
doc_len = train.text.apply(lambda doc: len(doc.split(' '))).to_numpy()
max_words = 500

# plot histogram
sns.histplot(doc_len)
plt.xlabel("Number of words", fontsize=13)
plt.ylabel("Count", fontsize=13)

print(f"Average document: {int(doc_len.mean())} words")
print(f"Longest document: {doc_len.max()} words")
print(f"Max required words: {max_words} words")
# Out:
# Average document: 515 words
# Longest document: 49039 words
# Max required words: 500 words

# %%
# removing any documents with len(words) >= 500
train500 = train[train.text.apply(lambda x: len(x.split(' '))) <= max_words]
test500 = test[test.text.apply(lambda x: len(x.split(' '))) <= max_words]

sns.histplot(train500.text.apply(lambda x: len(x.split(' '))))
plt.xlabel("Number of words", fontsize=13)
plt.ylabel("Count", fontsize=13)

print(f"Number of training examples: {train500.shape[0]}")
print(f"Number of test examples: {test500.shape[0]}")

print(f"Proportion of training examples: {100*train500.shape[0] / train.shape[0]:.2f}%")
print(f"Proportion of test examples: {100*test500.shape[0] / test.shape[0]:.2f}%")
# Out:
# Number of training examples: 6284
# Number of test examples: 1563
# Proportion of training examples: 76.05%
# Proportion of test examples: 76.02%

# %%
# get the number of words in each sample
doc_len = train500.text.apply(lambda doc: len(doc.split(' '))).to_numpy()
max_words = 500

print(f"Average document: {int(doc_len.mean())} words")
print(f"Longest document: {doc_len.max()} words")
print(f"Max required words: {max_words} words")
# Out:
# Average document: 229 words
# Longest document: 500 words
# Max required words: 500 words

# %%
vocab_count = Counter()
vocab_count500 = Counter()

train.text.str.split().apply(vocab_count.update)
train500.text.str.split().apply(vocab_count500.update)

vocab_count = dict(vocab_count)
vocab_count500 = dict(vocab_count500)


print(f"Number of distinct words in the original data set: {len(vocab_count)}")
print(f"Number of distinct words in the subset: {len(vocab_count500)}")

#sns.histplot(vocab_count.values())

print(f"Ratio: {100*len(vocab_count500) / len(vocab_count):.2f}")
# Out:
# Number of distinct words in the original data set: 290028
# Number of distinct words in the subset: 135779
# Ratio: 46.82

# %% [markdown]
# # Cleaned dataset

# %%
train = pd.read_csv(data_dir / 'train_cleaned.csv')#.drop('Unnamed: 0', axis=1)
test = pd.read_csv(data_dir / 'test_cleaned.csv')

print(train.shape)
train.head(5)
# Out:
# (8263, 3)
#    Unnamed: 0                                               text  sentiment
# 0           0  досудебн расследован факт покупк енпф пакет об...          0
# 1           1  медик рассказа состоян пострада мужчин котор с...          0
# 2           2  прошел год железнодорожн оператор запрет экспл...          0
# 3           3  итог  месяц  год территор республик выпущ  еди...          0
# 4           4  аста  ноябр kazakhstan today  агентств рк дел ...          0

# %%
# get the number of words in each sample
doc_len = train.text.apply(lambda doc: len(doc.split(' '))).to_numpy()
max_words = 500

# plot histogram
sns.histplot(doc_len)
plt.xlabel("Number of words", fontsize=13)
plt.ylabel("Count", fontsize=13)

print(f"Average document: {int(doc_len.mean())} words")
print(f"Longest document: {doc_len.max()} words")
print(f"Max required words: {max_words} words")
# Out:
# Average document: 436 words
# Longest document: 40554 words
# Max required words: 500 words

# %%
# removing any documents with len(words) >= 500
train500 = train[train.text.apply(lambda x: len(x.split(' '))) <= max_words]
test500 = test[test.text.apply(lambda x: len(x.split(' '))) <= max_words]

sns.histplot(train500.text.apply(lambda x: len(x.split(' '))))
plt.xlabel("Number of words", fontsize=13)
plt.ylabel("Count", fontsize=13)

print(f"Number of training examples: {train500.shape[0]}")
print(f"Number of test examples: {test500.shape[0]}")

print(f"Proportion of training examples: {100*train500.shape[0] / train.shape[0]:.2f}%")
print(f"Proportion of test examples: {100*test500.shape[0] / test.shape[0]:.2f}%")
# Out:
# Number of training examples: 6624
# Number of test examples: 1664
# Proportion of training examples: 80.16%
# Proportion of test examples: 80.93%

# %%
vocab_count = Counter()
vocab_count500 = Counter()

train.text.str.split().apply(vocab_count.update)
train500.text.str.split().apply(vocab_count500.update)

vocab_count = dict(vocab_count)
vocab_count500 = dict(vocab_count500)


print(f"Number of distinct words in the original data set: {len(vocab_count)}")
print(f"Number of distinct words in the subset: {len(vocab_count500)}")

#sns.histplot(vocab_count.values())

print(f"Ratio: {100*len(vocab_count500) / len(vocab_count):.2f}")
# Out:
# Number of distinct words in the original data set: 69503
# Number of distinct words in the subset: 37420
# Ratio: 53.84

# %%
embedded_dim = 30
max_seq_length = max_words

# %%
X_train = train500.text
y_train = train500.sentiment

# integer encode X_train
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)
tokenized = tokenizer.texts_to_sequences(X_train)
padded = pad_sequences(tokenized, maxlen=max_seq_length, padding='post')

# one-hot encode y_train
labels = to_categorical(y_train)

# %%
vocab_size = len(tokenizer.word_index) + 1

# %%
print(len(tokenized[0]), len(X_train[0].split(' ')))
print(tokenized[0])

print(X_train[0].split(' '))
# Out:
# 125 132
# [684, 259, 310, 674, 30, 1314, 432, 42, 542, 514, 1200, 1103, 14, 4, 12, 24, 43, 132, 554, 134, 430, 95, 157, 162, 2, 883, 1788, 966, 684, 259, 70, 751, 14, 4, 1625, 96, 1, 751, 14, 4, 871, 580, 392, 7, 274, 673, 3008, 2592, 8391, 328, 162, 96, 1, 411, 871, 580, 7, 1346, 1247, 80, 494, 971, 176, 334, 9, 72, 1788, 52, 162, 225, 3395, 70, 966, 334, 30, 52, 310, 197, 334, 8, 210, 443, 26, 29, 901, 57, 14, 4, 24, 334, 176, 437, 754, 8, 30, 151, 523, 137, 73, 11, 2593, 48, 274, 30, 63, 378, 20, 2295, 446, 98, 162, 4389, 591, 3499, 4890, 26, 279, 295, 884, 503, 399, 344, 1191, 747, 856]
# ['досудебн', 'расследован', 'факт', 'покупк', 'енпф', 'пакет', 'облигац', 'то', 'бузгул', 'аурум', 'начат', 'инициатив', 'национальн', 'банк', 'рк', 'сообщ', 'директор', 'департамент', 'защит', 'прав', 'потребител', 'финансов', 'услуг', 'нацбанк', 'казахста', 'александр', 'терент', 'основан', 'досудебн', 'расследован', 'стал', 'обращен', 'национальн', 'банк', 'письм', '', 'ноябр', '', 'год', 'обращен', 'национальн', 'банк', 'правоохранительн', 'орга', 'нам', 'эт', 'сделк', 'показа', 'сомнительн', 'недостаточн', 'корректн', 'поэт', 'нацбанк', '', 'ноябр', '', 'год', 'обрат', 'правоохранительн', 'орга', 'эт', 'мог', 'озвуч', 'сегодн', 'идет', 'следств', 'провод', 'проверк', '–', 'сказа', 'терент', '', 'декабр', 'нацбанк', 'заяв', 'знают', 'стал', 'основан', 'проверк', 'енпф', '', 'декабр', 'факт', 'проведен', 'проверк', 'а', 'един', 'накопительн', 'пенсион', 'фонд', 'подтверд', 'прессслужб', 'национальн', 'банк', 'сообщ', 'проверк', 'провод', 'операц', 'совершен', 'а', 'енпф', 'отношен', 'инвестирован', 'собствен', 'актив', 'такж', 'финрегулятор', 'сообща', 'сделк', 'енпф', 'сумм', 'пят', 'млрд', 'завед', 'уголовн', 'дел', 'нацбанк', 'заверя', 'все', 'происходя', 'затрагива', 'пенсион', 'накоплен', 'казахстанц', 'нашл', 'ошибк', 'текст', 'выдел', 'мыш', 'нажм', 'ctrlenter', '']

# %%
tokenizer.word_index
# Out:
# {'год': 1,
#  'казахста': 2,
#  'тенг': 3,
#  'банк': 4,
#  'котор': 5,
#  '—': 6,
#  'эт': 7,
#  'а': 8,
#  '–': 9,
#  'компан': 10,
#  'такж': 11,
#  'рк': 12,
#  'развит': 13,
#  'национальн': 14,
#  'проект': 15,
#  'нов': 16,
#  'област': 17,
#  'стран': 18,
#  'работ': 19,
#  'млрд': 20,
#  'дан': 21,
#  'сво': 22,
#  'казахстанск': 23,
#  'сообщ': 24,
#  'состав': 25,
#  'пенсион': 26,
#  'алмат': 27,
#  'перв': 28,
#  'фонд': 29,
#  'енпф': 30,
#  'автомобил': 31,
#  'отмет': 32,
#  'председател': 33,
#  'республик': 34,
#  'аста': 35,
#  'средств': 36,
#  'вопрос': 37,
#  'программ': 38,
#  'министр': 39,
#  'казахстан': 40,
#  'врем': 41,
#  'то': 42,
#  'директор': 43,
#  'экономик': 44,
#  'производств': 45,
#  'государствен': 46,
#  'будут': 47,
#  'сообща': 48,
#  'глав': 49,
#  'рынк': 50,
#  'январ': 51,
#  'декабр': 52,
#  'информац': 53,
#  'явля': 54,
#  'так': 55,
#  'наш': 56,
#  'прессслужб': 57,
#  'предприят': 58,
#  'город': 59,
#  'млн': 60,
#  'переда': 61,
#  'президент': 62,
#  'сумм': 63,
#  'тысяч': 64,
#  'министерств': 65,
#  'рамк': 66,
#  'государств': 67,
#  'мест': 68,
#  'итог': 69,
#  'стал': 70,
#  'инвестиц': 71,
#  'сказа': 72,
#  'актив': 73,
#  'управлен': 74,
#  'сам': 75,
#  'возможн': 76,
#  'говор': 77,
#  'лет': 78,
#  'участ': 79,
#  'сегодн': 80,
#  'друг': 81,
#  'международн': 82,
#  'нача': 83,
#  'тыс': 84,
#  'правительств': 85,
#  'цен': 86,
#  'центр': 87,
#  'месяц': 88,
#  'сообщен': 89,
#  'слов': 90,
#  'одн': 91,
#  'цел': 92,
#  'заместител': 93,
#  'сайт': 94,
#  'финансов': 95,
#  'ноябр': 96,
#  'поезд': 97,
#  'дел': 98,
#  'реализац': 99,
#  'счет': 100,
#  'работа': 101,
#  'числ': 102,
#  'строительств': 103,
#  'ход': 104,
#  'систем': 105,
#  'уровн': 106,
#  'крупн': 107,
#  'правлен': 108,
#  'дол': 109,
#  'деятельн': 110,
#  'рост': 111,
#  'суд': 112,
#  'ран': 113,
#  'доллар': 114,
#  'регион': 115,
#  'решен': 116,
#  'получ': 117,
#  'общ': 118,
#  'результат': 119,
#  'руководител': 120,
#  'прошл': 121,
#  'совет': 122,
#  'продукц': 123,
#  'представител': 124,
#  'организац': 125,
#  'комитет': 126,
#  'необходим': 127,
#  'соответств': 128,
#  'втор': 129,
#  'текущ': 130,
#  'г': 131,
#  'департамент': 132,
#  'планир': 133,
#  'прав': 134,
#  'экономическ': 135,
#  'бизнес': 136,
#  'собствен': 137,
#  'человек': 138,
#  'период': 139,
#  'размер': 140,
#  'основн': 141,
#  'акц': 142,
#  'процент': 143,
#  'созда': 144,
#  'завод': 145,
#  'услов': 146,
#  'занима': 147,
#  'напомн': 148,
#  'поддержк': 149,
#  'кром': 150,
#  'отношен': 151,
#  'связ': 152,
#  'лиц': 153,
#  'составля': 154,
#  'росс': 155,
#  'групп': 156,
#  'услуг': 157,
#  'социальн': 158,
#  'рассказа': 159,
#  'агентств': 160,
#  'инвестицион': 161,
#  'нацбанк': 162,
#  'заседан': 163,
#  'направлен': 164,
#  'обь': 165,
#  'след': 166,
#  'отрасл': 167,
#  'дет': 168,
#  'сред': 169,
#  'авт': 170,
#  'официальн': 171,
#  'тон': 172,
#  'промышлен': 173,
#  'показател': 174,
#  'больш': 175,
#  'провод': 176,
#  'сотрудничеств': 177,
#  '№': 178,
#  'объект': 179,
#  'сторон': 180,
#  'увелич': 181,
#  'район': 182,
#  'должн': 183,
#  'действ': 184,
#  'получен': 185,
#  'совместн': 186,
#  'вид': 187,
#  'продаж': 188,
#  'транспортн': 189,
#  'стоимост': 190,
#  'сфер': 191,
#  'октябр': 192,
#  'дом': 193,
#  'служб': 194,
#  'астан': 195,
#  'главн': 196,
#  'проведен': 197,
#  'мер': 198,
#  'миллиард': 199,
#  'безопасн': 200,
#  'сектор': 201,
#  'ситуац': 202,
#  'российск': 203,
#  'част': 204,
#  'специальн': 205,
#  'дорог': 206,
#  'мероприят': 207,
#  'объем': 208,
#  'населен': 209,
#  'един': 210,
#  'документ': 211,
#  'lada': 212,
#  'мир': 213,
#  'источник': 214,
#  'встреч': 215,
#  'участник': 216,
#  'пут': 217,
#  'наход': 218,
#  'открыт': 219,
#  'конц': 220,
#  'очен': 221,
#  'помощ': 222,
#  'качеств': 223,
#  'кажд': 224,
#  'заяв': 225,
#  'корреспондент': 226,
#  'согласн': 227,
#  'экспорт': 228,
#  'орган': 229,
#  'срок': 230,
#  'обеспечен': 231,
#  'количеств': 232,
#  'обществен': 233,
#  'байтерек': 234,
#  'счита': 235,
#  'народн': 236,
#  'машин': 237,
#  'ссылк': 238,
#  'настоя': 239,
#  'порядк': 240,
#  'предпринимател': 241,
#  'отечествен': 242,
#  'миллион': 243,
#  'портфел': 244,
#  'активн': 245,
#  'территор': 246,
#  'союз': 247,
#  'план': 248,
#  'доход': 249,
#  'создан': 250,
#  'вагон': 251,
#  'высок': 252,
#  'сем': 253,
#  'транспорт': 254,
#  'приня': 255,
#  'жител': 256,
#  'холдинг': 257,
#  'однак': 258,
#  'расследован': 259,
#  'евразийск': 260,
#  'рабоч': 261,
#  'случа': 262,
#  'отмеча': 263,
#  'окол': 264,
#  'последн': 265,
#  'пассажир': 266,
#  'деньг': 267,
#  'осуществля': 268,
#  'ден': 269,
#  'средн': 270,
#  'назарба': 271,
#  'инвестор': 272,
#  'ставк': 273,
#  'сделк': 274,
#  'момент': 275,
#  'стат': 276,
#  'сет': 277,
#  'известн': 278,
#  'накоплен': 279,
#  'повышен': 280,
#  'кредит': 281,
#  'пункт': 282,
#  'железнодорожн': 283,
#  'комплекс': 284,
#  'изменен': 285,
#  'ряд': 286,
#  'казинформ': 287,
#  'автомобильн': 288,
#  'иностра': 289,
#  'нужн': 290,
#  'аким': 291,
#  'люд': 292,
#  'имен': 293,
#  'акимат': 294,
#  'казахстанц': 295,
#  'полн': 296,
#  'станц': 297,
#  'должност': 298,
#  'модел': 299,
#  'единиц': 300,
#  'нурсулта': 301,
#  'производител': 302,
#  'специалист': 303,
#  'подчеркнул': 304,
#  'позвол': 305,
#  'курс': 306,
#  'сша': 307,
#  'могут': 308,
#  'сотрудник': 309,
#  'факт': 310,
#  'всем': 311,
#  'договор': 312,
#  'эксперт': 313,
#  'член': 314,
#  'очеред': 315,
#  'фот': 316,
#  'вклад': 317,
#  'снижен': 318,
#  'важн': 319,
#  'задач': 320,
#  'сентябр': 321,
#  'дальн': 322,
#  'финансирован': 323,
#  'закон': 324,
#  'подписа': 325,
#  'нескольк': 326,
#  'оказа': 327,
#  'поэт': 328,
#  'местн': 329,
#  'назнач': 330,
#  'нефт': 331,
#  'состоя': 332,
#  'пассажирск': 333,
#  'проверк': 334,
#  'причин': 335,
#  'требован': 336,
#  'процесс': 337,
#  'состоян': 338,
#  'дополнительн': 339,
#  'комисс': 340,
#  'капита': 341,
#  'инфраструктур': 342,
#  'добав': 343,
#  'выдел': 344,
#  'дал': 345,
#  'бишимба': 346,
#  'внутрен': 347,
#  'технолог': 348,
#  'энергетик': 349,
#  'акта': 350,
#  'ед': 351,
#  'товар': 352,
#  'расширен': 353,
#  'рейтинг': 354,
#  'ак': 355,
#  'обязательн': 356,
#  'финанс': 357,
#  'час': 358,
#  'руководств': 359,
#  'техническ': 360,
#  'премьерминистр': 361,
#  'управля': 362,
#  'ожида': 363,
#  'жил': 364,
#  'принят': 365,
#  'переработк': 366,
#  'порт': 367,
#  'увеличен': 368,
#  'ведомств': 369,
#  'изз': 370,
#  'газ': 371,
#  'жол': 372,
#  'соглашен': 373,
#  'политик': 374,
#  'оста': 375,
#  'торгов': 376,
#  'поясн': 377,
#  'пят': 378,
#  'оператор': 379,
#  'банковск': 380,
#  'уровен': 381,
#  'контрол': 382,
#  'спорт': 383,
#  'эффективн': 384,
#  'реализова': 385,
#  'времен': 386,
#  'учет': 387,
#  'независим': 388,
#  'принима': 389,
#  'институт': 390,
#  'рынок': 391,
#  'нам': 392,
#  'двух': 393,
#  'карт': 394,
#  'kazakhstan': 395,
#  'в': 396,
#  'легков': 397,
#  'участк': 398,
#  'текст': 399,
#  'пок': 400,
#  'переговор': 401,
#  'использован': 402,
#  'течен': 403,
#  'некотор': 404,
#  'оборудован': 405,
#  'сто': 406,
#  'имеет': 407,
#  'депозит': 408,
#  'риск': 409,
#  'ассоциац': 410,
#  'обрат': 411,
#  'раз': 412,
#  'клиент': 413,
#  'кредитн': 414,
#  'трет': 415,
#  'связа': 416,
#  'сравнен': 417,
#  'мнен': 418,
#  'начальник': 419,
#  'утилизац': 420,
#  'эксплуатац': 421,
#  'бюджет': 422,
#  'вкладчик': 423,
#  'сниз': 424,
#  'invest': 425,
#  'перевозк': 426,
#  'валют': 427,
#  'интерес': 428,
#  'предложен': 429,
#  'потребител': 430,
#  'выпуск': 431,
#  'облигац': 432,
#  'феврал': 433,
#  'тариф': 434,
#  'куандык': 435,
#  'проблем': 436,
#  'операц': 437,
#  'ответствен': 438,
#  'сдела': 439,
#  'бумаг': 440,
#  'особ': 441,
#  'форум': 442,
#  'накопительн': 443,
#  'областн': 444,
#  'движен': 445,
#  'уголовн': 446,
#  'нарушен': 447,
#  'грузов': 448,
#  'получа': 449,
#  'власт': 450,
#  'налогов': 451,
#  'автомоб': 452,
#  'школ': 453,
#  'вмест': 454,
#  'вниман': 455,
#  'значительн': 456,
#  'аэропорт': 457,
#  'обеспеч': 458,
#  'розничн': 459,
#  'образован': 460,
#  'сегодняшн': 461,
#  'выросл': 462,
#  'мощност': 463,
#  'аз': 464,
#  'обществ': 465,
#  'казкоммерцбанк': 466,
#  'кредитован': 467,
#  'техник': 468,
#  'мал': 469,
#  'нк': 470,
#  'прост': 471,
#  'аналогичн': 472,
#  'законодательств': 473,
#  'алматинск': 474,
#  'мног': 475,
#  'приобретен': 476,
#  'провед': 477,
#  'заявлен': 478,
#  'ответ': 479,
#  'образ': 480,
#  'спрос': 481,
#  'kase': 482,
#  'продолжа': 483,
#  'депутат': 484,
#  'привлечен': 485,
#  'баз': 486,
#  'проход': 487,
#  'указа': 488,
#  'бирж': 489,
#  'добыч': 490,
#  'структур': 491,
#  'жизн': 492,
#  'частн': 493,
#  'идет': 494,
#  'медицинск': 495,
#  'отдел': 496,
#  'маршрут': 497,
#  'ктж': 498,
#  'новост': 499,
#  'различн': 500,
#  'республиканск': 501,
#  'генеральн': 502,
#  'ошибк': 503,
#  'kaznex': 504,
#  'начал': 505,
#  'материал': 506,
#  'мен': 507,
#  'как': 508,
#  'выплат': 509,
#  'появ': 510,
#  'карагандинск': 511,
#  'провел': 512,
#  'касымбек': 513,
#  'аурум': 514,
#  'стандарт': 515,
#  'трлн': 516,
#  'частност': 517,
#  'прода': 518,
#  'регулирован': 519,
#  'гражда': 520,
#  'готов': 521,
#  'кита': 522,
#  'инвестирован': 523,
#  'предварительн': 524,
#  'миров': 525,
#  'bank': 526,
#  'вход': 527,
#  'делов': 528,
#  'университет': 529,
#  'лучш': 530,
#  'хот': 531,
#  'модернизац': 532,
#  'today': 533,
#  'займ': 534,
#  'акционер': 535,
#  'рубл': 536,
#  'недел': 537,
#  'личн': 538,
#  'продукт': 539,
#  'назначен': 540,
#  'платн': 541,
#  'бузгул': 542,
#  'региональн': 543,
#  'будущ': 544,
#  'субъект': 545,
#  'сбор': 546,
#  'универсиад': 547,
#  'городск': 548,
#  'рассматрива': 549,
#  'налог': 550,
#  'люб': 551,
#  'наибол': 552,
#  'сельск': 553,
#  'защит': 554,
#  'определен': 555,
#  'тем': 556,
#  'физическ': 557,
#  'заверш': 558,
#  'работник': 559,
#  'столиц': 560,
#  'электрон': 561,
#  'дня': 562,
#  'вицеминистр': 563,
#  'долж': 564,
#  'дела': 565,
#  'меморандум': 566,
#  'задержа': 567,
#  'таможен': 568,
#  'и': 569,
#  'торг': 570,
#  'бывш': 571,
#  'шымкент': 572,
#  'китайск': 573,
#  'бву': 574,
#  'предоставлен': 575,
#  'организова': 576,
#  'еаэс': 577,
#  'прям': 578,
#  'хозяйств': 579,
#  'орга': 580,
#  'улиц': 581,
#  'современ': 582,
#  'производствен': 583,
#  'лидер': 584,
#  'позиц': 585,
#  'предпринимательств': 586,
#  'предлага': 587,
#  'информацион': 588,
#  'приход': 589,
#  'детск': 590,
#  'все': 591,
#  'бренд': 592,
#  'реш': 593,
#  'метр': 594,
#  'центральн': 595,
#  'сми': 596,
#  'м': 597,
#  'основ': 598,
#  'сил': 599,
#  'благодар': 600,
#  'выступ': 601,
#  'выход': 602,
#  'команд': 603,
#  'заключ': 604,
#  'включ': 605,
#  'стар': 606,
#  'обязательств': 607,
#  'имуществ': 608,
#  'защ': 609,
#  'казахск': 610,
#  'qazkom': 611,
#  'мангистауск': 612,
#  'лин': 613,
#  'денежн': 614,
#  'конкурс': 615,
#  'определ': 616,
#  'выставк': 617,
#  'оплат': 618,
#  'еабр': 619,
#  'административн': 620,
#  'квартир': 621,
#  'комментар': 622,
#  'буд': 623,
#  'торговл': 624,
#  'сист': 625,
#  'подел': 626,
#  'пострада': 627,
#  'лиш': 628,
#  'август': 629,
#  'взнос': 630,
#  'морск': 631,
#  'произошл': 632,
#  'этап': 633,
#  'зон': 634,
#  'автоваз': 635,
#  'перспектив': 636,
#  'электроэнерг': 637,
#  'размещен': 638,
#  'фондов': 639,
#  'успешн': 640,
#  'пример': 641,
#  'партнер': 642,
#  'максимальн': 643,
#  'поруч': 644,
#  'вод': 645,
#  'категор': 646,
#  'отсутств': 647,
#  'груз': 648,
#  'процедур': 649,
#  'свыш': 650,
#  'труд': 651,
#  'поставк': 652,
#  'палат': 653,
#  'выда': 654,
#  'соста': 655,
#  'долг': 656,
#  'коммерческ': 657,
#  'юридическ': 658,
#  'разработа': 659,
#  'клуб': 660,
#  'назад': 661,
#  'пост': 662,
#  'журналист': 663,
#  'объединен': 664,
#  'полност': 665,
#  'направл': 666,
#  'костанайск': 667,
#  'конкуренц': 668,
#  'подготовк': 669,
#  'дне': 670,
#  'ближайш': 671,
#  'сократ': 672,
#  'показа': 673,
#  'покупк': 674,
#  'отделен': 675,
#  'спортивн': 676,
#  'женис': 677,
#  'занят': 678,
#  'инструмент': 679,
#  'значен': 680,
#  'прогноз': 681,
#  'центркред': 682,
#  'железн': 683,
#  'досудебн': 684,
#  'zakonkz': 685,
#  'сборк': 686,
#  'автобус': 687,
#  'достаточн': 688,
#  'пришл': 689,
#  'июл': 690,
#  'разработк': 691,
#  'призна': 692,
#  'москв': 693,
#  'месторожден': 694,
#  'режим': 695,
#  'кодекс': 696,
#  'прокомментирова': 697,
#  'ведет': 698,
#  'плат': 699,
#  'принцип': 700,
#  'оценк': 701,
#  'практическ': 702,
#  'расход': 703,
#  'исследован': 704,
#  'европейск': 705,
#  'энерг': 706,
#  'здравоохранен': 707,
#  'коррупц': 708,
#  'половин': 709,
#  'предполага': 710,
#  'е': 711,
#  'женщин': 712,
#  'развива': 713,
#  'перевозок': 714,
#  'авиакомпан': 715,
#  'олимпийск': 716,
#  'культур': 717,
#  'о': 718,
#  'внешн': 719,
#  'улучшен': 720,
#  'ежегодн': 721,
#  'билет': 722,
#  'летн': 723,
#  'продолж': 724,
#  'апрел': 725,
#  'налич': 726,
#  'никак': 727,
#  'предлож': 728,
#  'собра': 729,
#  'июн': 730,
#  'установлен': 731,
#  'экологическ': 732,
#  'содержан': 733,
#  'тг': 734,
#  'км': 735,
#  'повыс': 736,
#  'актоб': 737,
#  'строительн': 738,
#  'народ': 739,
#  'заключен': 740,
#  'тимур': 741,
#  'экспортн': 742,
#  'поручен': 743,
#  'todaykz': 744,
#  'дума': 745,
#  'откр': 746,
#  'нажм': 747,
#  'данияр': 748,
#  'здоров': 749,
#  'площадк': 750,
#  'обращен': 751,
#  'facebook': 752,
#  'устькаменогорск': 753,
#  'совершен': 754,
#  'постановлен': 755,
#  'павлодарск': 756,
#  'fortebank': 757,
#  'опубликова': 758,
#  'внедрен': 759,
#  'караганд': 760,
#  'анализ': 761,
#  'самолет': 762,
#  'имеют': 763,
#  'каса': 764,
#  'за': 765,
#  'kapitalkz': 766,
#  'годов': 767,
#  'қазақста': 768,
#  'денег': 769,
#  'федерац': 770,
#  'пенс': 771,
#  'сохран': 772,
#  'стратегическ': 773,
#  'ми': 774,
#  'запуск': 775,
#  'мажилис': 776,
#  'трех': 777,
#  'послан': 778,
#  'обслуживан': 779,
#  'инфляц': 780,
#  'дат': 781,
#  'производ': 782,
#  'остальн': 783,
#  'использова': 784,
#  'назва': 785,
#  'евр': 786,
#  'установл': 787,
#  'hyundai': 788,
#  'переход': 789,
#  'отдельн': 790,
#  'сраз': 791,
#  'прот': 792,
#  'индекс': 793,
#  'сокращен': 794,
#  'инновацион': 795,
#  'сегмент': 796,
#  'меньш': 797,
#  'ресурс': 798,
#  'обсужден': 799,
#  'самрукэнерг': 800,
#  'разн': 801,
#  'бюджетн': 802,
#  'отход': 803,
#  'ма': 804,
#  'топлив': 805,
#  'совещан': 806,
#  'роп': 807,
#  'положительн': 808,
#  'игр': 809,
#  'парламент': 810,
#  'реконструкц': 811,
#  'исполнительн': 812,
#  'несмотр': 813,
#  'ключев': 814,
#  'мы': 815,
#  'поч': 816,
#  'заня': 817,
#  'автор': 818,
#  'сулеймен': 819,
#  'передач': 820,
#  'полиц': 821,
#  'публикац': 822,
#  'стабильн': 823,
#  'ин': 824,
#  'рф': 825,
#  'имеющ': 826,
#  'незакон': 827,
#  'эксп': 828,
#  'предоставля': 829,
#  'тэц': 830,
#  'русла': 831,
#  'дочерн': 832,
#  'реальн': 833,
#  'либ': 834,
#  'чист': 835,
#  'пробл': 836,
#  'корпорац': 837,
#  'существ': 838,
#  'естествен': 839,
#  'площад': 840,
#  'угл': 841,
#  'подозрева': 842,
#  'намер': 843,
#  'минут': 844,
#  'топ': 845,
#  'дорожн': 846,
#  'шест': 847,
#  'состо': 848,
#  'особен': 849,
#  'отчетн': 850,
#  'костана': 851,
#  'здан': 852,
#  'наблюда': 853,
#  'достижен': 854,
#  'предусмотр': 855,
#  'ctrlenter': 856,
#  'реч': 857,
#  'километр': 858,
#  'профессиональн': 859,
#  'зарегистрирова': 860,
#  'сложн': 861,
#  'постро': 862,
#  'популярн': 863,
#  'вошл': 864,
#  'представля': 865,
#  'корпоративн': 866,
#  'покупател': 867,
#  'зат': 868,
#  'toyota': 869,
#  'стратег': 870,
#  'правоохранительн': 871,
#  'льготн': 872,
#  'обсужда': 873,
#  'скор': 874,
#  'ниж': 875,
#  'предусматрива': 876,
#  'представ': 877,
#  'молод': 878,
#  'завершен': 879,
#  'самрукказын': 880,
#  'положен': 881,
#  'назарбаев': 882,
#  'александр': 883,
#  'нашл': 884,
#  'предостав': 885,
#  'потенциа': 886,
#  'украин': 887,
#  'ограничен': 888,
#  'постоя': 889,
#  'штраф': 890,
#  'смогут': 891,
#  'проинформирова': 892,
#  'коммуникац': 893,
#  'резк': 894,
#  'оказыва': 895,
#  'урок': 896,
#  'доходн': 897,
#  'оп': 898,
#  'вперв': 899,
#  'обучен': 900,
#  'подтверд': 901,
#  'издел': 902,
#  'гарант': 903,
#  'просмотр': 904,
#  'бишимбаев': 905,
#  'позволя': 906,
#  'наук': 907,
#  'атамек': 908,
#  'хорош': 909,
#  'усил': 910,
#  'посет': 911,
#  'выполня': 912,
#  'располож': 913,
#  'уральск': 914,
#  'свободн': 915,
#  'ебрр': 916,
#  'долгосрочн': 917,
#  'доступ': 918,
#  'чемпион': 919,
#  'темп': 920,
#  'соответствен': 921,
#  'рассмотрен': 922,
#  'марк': 923,
#  'событ': 924,
#  'выделен': 925,
#  'казтаг': 926,
#  'вырос': 927,
#  'механизм': 928,
#  'ввод': 929,
#  'ликвидн': 930,
#  'мужчин': 931,
#  'норм': 932,
#  'польз': 933,
#  'монопол': 934,
#  'жамбылск': 935,
#  'кред': 936,
#  'прессконференц': 937,
#  'содейств': 938,
#  'позж': 939,
#  'превыша': 940,
#  'гост': 941,
#  'сервис': 942,
#  'потенциальн': 943,
#  'протяжен': 944,
#  'платеж': 945,
#  'противодейств': 946,
#  'европ': 947,
#  'выш': 948,
#  'арестова': 949,
#  'акиш': 950,
#  'выпуска': 951,
#  'технологическ': 952,
#  'те': 953,
#  'снг': 954,
#  'арест': 955,
#  'представл': 956,
#  'петропавловск': 957,
#  'станет': 958,
#  'снят': 959,
#  'акт': 960,
#  'конкретн': 961,
#  'индивидуальн': 962,
#  'организатор': 963,
#  'дам': 964,
#  'кит': 965,
#  'основан': 966,
#  'интерфаксказахста': 967,
#  'приб': 968,
#  'запланирова': 969,
#  'аппарат': 970,
#  'следств': 971,
#  'рейс': 972,
#  'ведущ': 973,
#  'уда': 974,
#  'паден': 975,
#  'исполнен': 976,
#  'т': 977,
#  'рол': 978,
#  'регистрац': 979,
#  'номер': 980,
#  'функц': 981,
#  'возглавля': 982,
#  'выбор': 983,
#  'подход': 984,
#  'ваш': 985,
#  'гражданск': 986,
#  'фактор': 987,
#  'регулятор': 988,
#  'родител': 989,
#  'подобн': 990,
#  'благотворительн': 991,
#  'development': 992,
#  'подробн': 993,
#  'нпп': 994,
#  'поступ': 995,
#  'поскольк': 996,
#  'начина': 997,
#  'род': 998,
#  'х': 999,
#  'устойчив': 1000,
#  ...}

# %%
model = Sequential()
model.add(layers.Embedding(input_dim=vocab_size,
                           output_dim=embedded_dim,
                           input_length=max_seq_length))
model.add(layers.Flatten())
model.add(layers.Dense(3, activation='softmax'))

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

print(model.summary())
model.fit(padded, labels, batch_size=32, epochs=10, verbose=1, validation_split=0.2)
# Out:
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_18 (Embedding)    (None, 500, 30)           1122990
#
#  flatten_11 (Flatten)        (None, 15000)             0
#
#  dense_15 (Dense)            (None, 3)                 45003
#
# =================================================================
# Total params: 1,167,993
# Trainable params: 1,167,993
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 166/166 [==============================] - 2s 11ms/step - loss: 0.9680 - accuracy: 0.5218 - val_loss: 0.7954 - val_accuracy: 0.6234
# Epoch 2/10
# 166/166 [==============================] - 2s 11ms/step - loss: 0.5597 - accuracy: 0.7869 - val_loss: 0.6736 - val_accuracy: 0.6974
# Epoch 3/10
# 166/166 [==============================] - 2s 11ms/step - loss: 0.3002 - accuracy: 0.9045 - val_loss: 0.7000 - val_accuracy: 0.6830
# Epoch 4/10
# 166/166 [==============================] - 2s 11ms/step - loss: 0.1906 - accuracy: 0.9389 - val_loss: 0.7143 - val_accuracy: 0.7140
# Epoch 5/10
# 166/166 [==============================] - 2s 11ms/step - loss: 0.1512 - accuracy: 0.9511 - val_loss: 0.7472 - val_accuracy: 0.7087
# Epoch 6/10
# 166/166 [==============================] - 2s 11ms/step - loss: 0.1335 - accuracy: 0.9513 - val_loss: 0.7798 - val_accuracy: 0.7094
# Epoch 7/10
# 166/166 [==============================] - 2s 11ms/step - loss: 0.1215 - accuracy: 0.9558 - val_loss: 0.8051 - val_accuracy: 0.7064
# Epoch 8/10
# 166/166 [==============================] - 2s 11ms/step - loss: 0.1185 - accuracy: 0.9566 - val_loss: 0.8351 - val_accuracy: 0.6981
# Epoch 9/10
# 166/166 [==============================] - 2s 11ms/step - loss: 0.1149 - accuracy: 0.9558 - val_loss: 0.8523 - val_accuracy: 0.6943
# Epoch 10/10
# 166/166 [==============================] - 2s 10ms/step - loss: 0.1090 - accuracy: 0.9560 - val_loss: 0.8548 - val_accuracy: 0.7079

# %%
def plot_model(model):
    
    num_epochs = len(model.history.history['accuracy'])
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
    
    ax1.plot(model.history.history['accuracy'])
    ax1.plot(model.history.history['val_accuracy'])
    ax1.set_title("Accuracy", fontsize=13)
    ax1.set_ylabel('Accuracy', fontsize=13)
    ax1.set_xlabel('Number of epochs', fontsize=13)
    ax1.set_xticks(range(0, num_epochs), range(1, num_epochs + 1))
    ax1.legend(['Train', 'Validation'], loc='upper left')
    
    ax2.plot(model.history.history['loss'])
    ax2.plot(model.history.history['val_loss'])
    ax2.set_title("Loss", fontsize=13)
    ax2.set_ylabel('Loss', fontsize=13)
    ax2.set_xlabel('Number of epochs', fontsize=13)
    ax2.set_xticks(range(0, num_epochs), range(1, num_epochs + 1))
    ax2.legend(['Train', 'Validation'], loc='upper left')

    return fig

a = plot_model(model)

# a.savefig(plots_dir / model['Name'])

# %%
model = Sequential()
model.add(layers.Embedding(vocab_size, embed_dim, input_length=max_seq_length))
model.add(layers.LSTM(256))

model.add(layers.Dropout(0.5))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))

model.add(layers.Dense(512, activation='relu'))

model.add(layers.Dropout(0.5))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(3, activation='softmax'))
model.compile(loss = 'categorical_crossentropy', optimizer='adam',metrics = ['accuracy'])
print(model.summary())
model.fit(padded, labels, batch_size=32, epochs=10, verbose=1, validation_split=0.2)
# Out:
# Model: "sequential_30"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_25 (Embedding)    (None, 500, 30)           1122990
#
#  lstm_10 (LSTM)              (None, 256)               293888
#
#  dropout (Dropout)           (None, 256)               0
#
#  batch_normalization (BatchN  (None, 256)              1024
#  ormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_22 (Dense)            (None, 512)               131584
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_23 (Dense)            (None, 3)                 1539
#
# =================================================================
# Total params: 1,553,073
# Trainable params: 1,551,537
# Non-trainable params: 1,536
# _________________________________________________________________
# None
# Epoch 1/10
# 166/166 [==============================] - 101s 598ms/step - loss: 1.6176 - accuracy: 0.3754 - val_loss: 1.0273 - val_accuracy: 0.3804
# Epoch 2/10
#  62/166 [==========>...................] - ETA: 56s - loss: 1.3776 - accuracy: 0.3831
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [179], in <cell line: 20>()
#      18 model.compile(loss = 'categorical_crossentropy', optimizer='adam',metrics = ['accuracy'])
#      19 print(model.summary())
# ---> 20 model.fit(padded, labels, batch_size=32, epochs=10, verbose=1, validation_split=0.2)
#
# File ~/miniconda3/envs/ukraine/lib/python3.10/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/ukraine/lib/python3.10/site-packages/keras/engine/training.py:1384, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1377 with tf.profiler.experimental.Trace(
#    1378     'train',
#    1379     epoch_num=epoch,
#    1380     step_num=step,
#    1381     batch_size=batch_size,
#    1382     _r=1):
#    1383   callbacks.on_train_batch_begin(step)
# -> 1384   tmp_logs = self.train_function(iterator)
#    1385   if data_handler.should_sync:
#    1386     context.async_wait()
#
# File ~/miniconda3/envs/ukraine/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/ukraine/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniconda3/envs/ukraine/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~/miniconda3/envs/ukraine/lib/python3.10/site-packages/tensorflow/python/eager/function.py:2956, in Function.__call__(self, *args, **kwargs)
#    2953 with self._lock:
#    2954   (graph_function,
#    2955    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2956 return graph_function._call_flat(
#    2957     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/miniconda3/envs/ukraine/lib/python3.10/site-packages/tensorflow/python/eager/function.py:1853, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1849 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1850 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1851     and executing_eagerly):
#    1852   # No tape is watching; skip to running the function.
# -> 1853   return self._build_call_outputs(self._inference_function.call(
#    1854       ctx, args, cancellation_manager=cancellation_manager))
#    1855 forward_backward = self._select_forward_and_backward_functions(
#    1856     args,
#    1857     possible_gradient_type,
#    1858     executing_eagerly)
#    1859 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniconda3/envs/ukraine/lib/python3.10/site-packages/tensorflow/python/eager/function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File ~/miniconda3/envs/ukraine/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
def plot_model(model):
    
    num_epochs = len(model.history.history['accuracy'])
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
    
    ax1.plot(model.history.history['accuracy'])
    ax1.plot(model.history.history['val_accuracy'])
    ax1.set_title("Accuracy", fontsize=13)
    ax1.set_ylabel('Accuracy', fontsize=13)
    ax1.set_xlabel('Number of epochs', fontsize=13)
    ax1.set_xticks(range(0, num_epochs), range(1, num_epochs + 1))
    ax1.legend(['Train', 'Validation'], loc='upper left')
    
    ax2.plot(model.history.history['loss'])
    ax2.plot(model.history.history['val_loss'])
    ax2.set_title("Loss", fontsize=13)
    ax2.set_ylabel('Loss', fontsize=13)
    ax2.set_xlabel('Number of epochs', fontsize=13)
    ax2.set_xticks(range(0, num_epochs), range(1, num_epochs + 1))
    ax2.legend(['Train', 'Validation'], loc='upper left')

    return fig

a = plot_model(model)

# a.savefig(plots_dir / model['Name'])

# %%
def fit_model(model, X_train, y_train, batch_size, num_epochs, val):
    model.fit(X_train,
              y_train,
              batch_size,
              epochs=num_epochs,
              validation_split=val)
    
def create_json(model, training_time):
    
    today = date.today()
    now = datetime.now().time()
    
    model_json = {
        "Date": today.strftime("%d/%m/%Y"),
        "Time": now.strftime("%H:%M:%S"),
        "Name": model.name,
        "History": model.history.history,
        "Model": model.to_json(),
        "Vocab size": vocab_size,
        "Embedding size": embedding_size,
        "Max words": max_words,
        "Epochs": num_epochs,
        "Validation split:": val,
        "Training time": training_time
    }
    return model_json

def plot_model(model):
    
    num_epochs = len(model.history.history['accuracy'])
    
    fig1, acc = plt.subplots(figsize=(8, 8), constrained_layout=True)    
    acc.plot(model.history.history['accuracy'])
    acc.plot(model.history.history['val_accuracy'])
    acc.set_title("Accuracy", fontsize=13)
    acc.set_ylabel('Accuracy', fontsize=13)
    acc.set_xlabel('Number of epochs', fontsize=13)
    acc.set_xticks(range(0, num_epochs), range(1, num_epochs + 1))
    acc.legend(['Train', 'Validation'], loc='upper left')
    
    fig2, loss = plt.subplots(figsize=(8, 8), constrained_layout=True)
    loss.plot(model.history.history['loss'])
    loss.plot(model.history.history['val_loss'])
    loss.set_title("Loss", fontsize=13)
    loss.set_ylabel('Loss', fontsize=13)
    loss.set_xlabel('Number of epochs', fontsize=13)
    loss.set_xticks(range(0, num_epochs), range(1, num_epochs + 1))
    loss.legend(['Train', 'Validation'], loc='upper left')

    return fig1, fig2
    
def train_and_save(X_train, y_train, model, batch_size, num_epochs, val):
    
    start = time()
    fit_model(model, X_train, y_train, batch_size, num_epochs, val)
    training_time = time()-start
    
    model_json = create_json(model, training_time)

    acc, loss = plot_model(model)

    acc.savefig(plots_dir / (model_json['Name'] + '_acc'))
    loss.figure.savefig(plots_dir / (model_json['Name'] + '_loss'))


    with open(models_dir / (model_json["Name"] + '.json'), 'w') as json_file:
        json.dump(model_json, json_file)

# %% [markdown]
# ## Base Model CNN
#
# Training base models using CNN units in the range of 64, 128, 256, 512, 1024, 2048

# %%
from core.ukraine_utilities import TrainAndSave
# Out:
# Traceback (most recent call last):
#
#   File ~/miniconda3/envs/ukraine/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3369 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Input In [369] in <cell line: 1>
#     from core.ukraine_utilities import TrainAndSave
#
#   File ~/Documents/UkraineWarSentimentAnalysis/core/ukraine_utilities.py:7
#     from sklearn.preprocessing import LabelEncoder]
#                                                   ^
# SyntaxError: unmatched ']'

# %%
vocab_size = len(tokenizer.word_index) + 1
embedding_size = 30
max_words = 500
cnn_units = [64*2**i for i in range(0,6)]
num_epochs = 10
val = 0.2

for i in cnn_units:
    
    name = 'base_cnn' + f'_{i}'
    
    model = Sequential(name=name)
    model.add(layers.Embedding(vocab_size, embedding_size, input_length=max_seq_length))
    model.add(layers.Conv1D(i, 3, padding='valid', activation='relu', strides=1))
    model.add(layers.GlobalMaxPooling1D())
    model.add(layers.Dense(3, activation='softmax'))
    model.compile(loss = 'categorical_crossentropy', optimizer='adam',metrics = ['accuracy'])
    
    train_and_save(padded, labels, model, 32, num_epochs, val)
# Out:
# Epoch 1/10
# 166/166 [==============================] - 3s 17ms/step - loss: 0.9831 - accuracy: 0.5018 - val_loss: 0.8886 - val_accuracy: 0.5608
# Epoch 2/10
# 166/166 [==============================] - 3s 16ms/step - loss: 0.7371 - accuracy: 0.6752 - val_loss: 0.7268 - val_accuracy: 0.6596
# Epoch 3/10
# 166/166 [==============================] - 3s 17ms/step - loss: 0.5456 - accuracy: 0.7886 - val_loss: 0.6651 - val_accuracy: 0.6921
# Epoch 4/10
# 166/166 [==============================] - 3s 17ms/step - loss: 0.3899 - accuracy: 0.8636 - val_loss: 0.6636 - val_accuracy: 0.7125
# Epoch 5/10
# 166/166 [==============================] - 3s 18ms/step - loss: 0.2783 - accuracy: 0.9053 - val_loss: 0.6908 - val_accuracy: 0.7117
# Epoch 6/10
# 166/166 [==============================] - 3s 18ms/step - loss: 0.2121 - accuracy: 0.9207 - val_loss: 0.7427 - val_accuracy: 0.7057
# Epoch 7/10
# 166/166 [==============================] - 3s 17ms/step - loss: 0.1747 - accuracy: 0.9294 - val_loss: 0.7698 - val_accuracy: 0.7125
# Epoch 8/10
# 166/166 [==============================] - 3s 18ms/step - loss: 0.1510 - accuracy: 0.9353 - val_loss: 0.8426 - val_accuracy: 0.6981
# Epoch 9/10
# 166/166 [==============================] - 3s 19ms/step - loss: 0.1388 - accuracy: 0.9360 - val_loss: 0.8454 - val_accuracy: 0.7019
# Epoch 10/10
# 166/166 [==============================] - 3s 18ms/step - loss: 0.1319 - accuracy: 0.9421 - val_loss: 0.8669 - val_accuracy: 0.7087
# Epoch 1/10
# 166/166 [==============================] - 4s 25ms/step - loss: 0.9723 - accuracy: 0.4969 - val_loss: 0.8833 - val_accuracy: 0.5585
# Epoch 2/10
# 166/166 [==============================] - 4s 26ms/step - loss: 0.7293 - accuracy: 0.6767 - val_loss: 0.7199 - val_accuracy: 0.6747
# Epoch 3/10
# 166/166 [==============================] - 4s 24ms/step - loss: 0.5298 - accuracy: 0.7924 - val_loss: 0.6701 - val_accuracy: 0.6815
# Epoch 4/10
# 166/166 [==============================] - 4s 24ms/step - loss: 0.3742 - accuracy: 0.8568 - val_loss: 0.6882 - val_accuracy: 0.6996
# Epoch 5/10
# 166/166 [==============================] - 4s 24ms/step - loss: 0.2614 - accuracy: 0.9047 - val_loss: 0.7527 - val_accuracy: 0.7004
# Epoch 6/10
# 166/166 [==============================] - 4s 23ms/step - loss: 0.1994 - accuracy: 0.9168 - val_loss: 0.8230 - val_accuracy: 0.6808
# Epoch 7/10
# 166/166 [==============================] - 4s 23ms/step - loss: 0.1649 - accuracy: 0.9281 - val_loss: 0.8356 - val_accuracy: 0.6921
# Epoch 8/10
# 166/166 [==============================] - 4s 23ms/step - loss: 0.1425 - accuracy: 0.9373 - val_loss: 0.8869 - val_accuracy: 0.6913
# Epoch 9/10
# 166/166 [==============================] - 4s 24ms/step - loss: 0.1269 - accuracy: 0.9434 - val_loss: 0.9266 - val_accuracy: 0.6943
# Epoch 10/10
# 166/166 [==============================] - 4s 24ms/step - loss: 0.1200 - accuracy: 0.9460 - val_loss: 0.9656 - val_accuracy: 0.6898
# Epoch 1/10
# 166/166 [==============================] - 7s 40ms/step - loss: 0.9616 - accuracy: 0.5154 - val_loss: 0.8281 - val_accuracy: 0.5925
# Epoch 2/10
# 166/166 [==============================] - 7s 40ms/step - loss: 0.6950 - accuracy: 0.6952 - val_loss: 0.6853 - val_accuracy: 0.6921
# Epoch 3/10
# 166/166 [==============================] - 6s 38ms/step - loss: 0.4782 - accuracy: 0.8126 - val_loss: 0.6882 - val_accuracy: 0.7049
# Epoch 4/10
# 166/166 [==============================] - 6s 35ms/step - loss: 0.3162 - accuracy: 0.8770 - val_loss: 0.7410 - val_accuracy: 0.7026
# Epoch 5/10
# 166/166 [==============================] - 6s 35ms/step - loss: 0.2220 - accuracy: 0.9158 - val_loss: 0.8443 - val_accuracy: 0.6921
# Epoch 6/10
# 166/166 [==============================] - 6s 35ms/step - loss: 0.1727 - accuracy: 0.9281 - val_loss: 0.9245 - val_accuracy: 0.6792
# Epoch 7/10
# 166/166 [==============================] - 6s 35ms/step - loss: 0.1440 - accuracy: 0.9373 - val_loss: 0.9563 - val_accuracy: 0.6943
# Epoch 8/10
# 166/166 [==============================] - 6s 34ms/step - loss: 0.1310 - accuracy: 0.9406 - val_loss: 1.0265 - val_accuracy: 0.6860
# Epoch 9/10
# 166/166 [==============================] - 7s 41ms/step - loss: 0.1242 - accuracy: 0.9407 - val_loss: 1.0470 - val_accuracy: 0.6966
# Epoch 10/10
# 166/166 [==============================] - 6s 39ms/step - loss: 0.1137 - accuracy: 0.9441 - val_loss: 1.0965 - val_accuracy: 0.6838
# Epoch 1/10
# 166/166 [==============================] - 11s 63ms/step - loss: 0.9514 - accuracy: 0.5220 - val_loss: 0.8100 - val_accuracy: 0.6060
# Epoch 2/10
# 166/166 [==============================] - 10s 63ms/step - loss: 0.6761 - accuracy: 0.6992 - val_loss: 0.6722 - val_accuracy: 0.7026
# Epoch 3/10
# 166/166 [==============================] - 10s 63ms/step - loss: 0.4606 - accuracy: 0.8147 - val_loss: 0.6823 - val_accuracy: 0.7087
# Epoch 4/10
# 166/166 [==============================] - 10s 62ms/step - loss: 0.3059 - accuracy: 0.8813 - val_loss: 0.7537 - val_accuracy: 0.6936
# Epoch 5/10
# 166/166 [==============================] - 10s 60ms/step - loss: 0.2136 - accuracy: 0.9124 - val_loss: 0.8734 - val_accuracy: 0.6845
# Epoch 6/10
# 166/166 [==============================] - 11s 66ms/step - loss: 0.1761 - accuracy: 0.9300 - val_loss: 0.9132 - val_accuracy: 0.6928
# Epoch 7/10
# 166/166 [==============================] - 12s 72ms/step - loss: 0.1475 - accuracy: 0.9347 - val_loss: 0.9724 - val_accuracy: 0.6921
# Epoch 8/10
# 166/166 [==============================] - 11s 67ms/step - loss: 0.1323 - accuracy: 0.9394 - val_loss: 0.9944 - val_accuracy: 0.6943
# Epoch 9/10
# 166/166 [==============================] - 11s 65ms/step - loss: 0.1251 - accuracy: 0.9406 - val_loss: 1.0618 - val_accuracy: 0.6951
# Epoch 10/10
# 166/166 [==============================] - 11s 65ms/step - loss: 0.1157 - accuracy: 0.9421 - val_loss: 1.0885 - val_accuracy: 0.6966
# Epoch 1/10
# 166/166 [==============================] - 21s 122ms/step - loss: 0.9329 - accuracy: 0.5333 - val_loss: 0.7777 - val_accuracy: 0.6332
# Epoch 2/10
# 166/166 [==============================] - 19s 114ms/step - loss: 0.6418 - accuracy: 0.7216 - val_loss: 0.6883 - val_accuracy: 0.6815
# Epoch 3/10
# 166/166 [==============================] - 19s 114ms/step - loss: 0.4216 - accuracy: 0.8336 - val_loss: 0.7108 - val_accuracy: 0.7026
# Epoch 4/10
# 166/166 [==============================] - 19s 115ms/step - loss: 0.2738 - accuracy: 0.8917 - val_loss: 0.8065 - val_accuracy: 0.6974
# Epoch 5/10
# 166/166 [==============================] - 19s 117ms/step - loss: 0.1963 - accuracy: 0.9207 - val_loss: 0.9059 - val_accuracy: 0.6875
# Epoch 6/10
# 166/166 [==============================] - 20s 118ms/step - loss: 0.1630 - accuracy: 0.9324 - val_loss: 0.9841 - val_accuracy: 0.6891
# Epoch 7/10
# 166/166 [==============================] - 19s 116ms/step - loss: 0.1439 - accuracy: 0.9360 - val_loss: 1.0576 - val_accuracy: 0.6838
# Epoch 8/10
# 166/166 [==============================] - 19s 114ms/step - loss: 0.1303 - accuracy: 0.9407 - val_loss: 1.0922 - val_accuracy: 0.6830
# Epoch 9/10
# 166/166 [==============================] - 19s 114ms/step - loss: 0.1229 - accuracy: 0.9447 - val_loss: 1.1650 - val_accuracy: 0.6830
# Epoch 10/10
# 166/166 [==============================] - 19s 114ms/step - loss: 0.1174 - accuracy: 0.9426 - val_loss: 1.1512 - val_accuracy: 0.6762
# Epoch 1/10
# 166/166 [==============================] - 42s 252ms/step - loss: 0.8988 - accuracy: 0.5622 - val_loss: 0.7453 - val_accuracy: 0.6657
# Epoch 2/10
# 166/166 [==============================] - 42s 251ms/step - loss: 0.5980 - accuracy: 0.7386 - val_loss: 0.6667 - val_accuracy: 0.7291
# Epoch 3/10
# 166/166 [==============================] - 41s 250ms/step - loss: 0.3794 - accuracy: 0.8503 - val_loss: 0.7296 - val_accuracy: 0.6974
# Epoch 4/10
# 166/166 [==============================] - 42s 251ms/step - loss: 0.2507 - accuracy: 0.9005 - val_loss: 0.8390 - val_accuracy: 0.7042
# Epoch 5/10
# 166/166 [==============================] - 42s 250ms/step - loss: 0.1841 - accuracy: 0.9272 - val_loss: 0.9154 - val_accuracy: 0.7026
# Epoch 6/10
# 166/166 [==============================] - 42s 251ms/step - loss: 0.1576 - accuracy: 0.9336 - val_loss: 1.0005 - val_accuracy: 0.7011
# Epoch 7/10
# 166/166 [==============================] - 42s 251ms/step - loss: 0.1374 - accuracy: 0.9389 - val_loss: 1.0503 - val_accuracy: 0.6996
# Epoch 8/10
# 166/166 [==============================] - 41s 250ms/step - loss: 0.1333 - accuracy: 0.9457 - val_loss: 1.0829 - val_accuracy: 0.6883
# Epoch 9/10
# 166/166 [==============================] - 41s 249ms/step - loss: 0.1224 - accuracy: 0.9455 - val_loss: 1.2026 - val_accuracy: 0.6642
# Epoch 10/10
# 166/166 [==============================] - 42s 250ms/step - loss: 0.1084 - accuracy: 0.9483 - val_loss: 1.1136 - val_accuracy: 0.7004

# %% [markdown]
# # Deep CNNs
#
# ### 2-layer CNN

# %%
vocab_size = len(tokenizer.word_index) + 1
embedding_size = 30
max_words = 500
cnn_units = [64*2**i for i in range(0,6)]
num_epochs = 10
val = 0.2

for i in range(0, 5):
    units = 2048 / 2**i
    name = name = 'two_layer_cnn' + f'_{int(units)}'
    model = Sequential(name=name)
    model.add(layers.Embedding(vocab_size, embedding_size, input_length=max_seq_length))
    model.add(layers.Conv1D(512, 3, padding='valid', activation='relu', strides=1))
    model.add(layers.GlobalMaxPooling1D())
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(units, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(3, activation='softmax'))
    model.compile(loss = 'categorical_crossentropy', optimizer='adam',metrics = ['accuracy'])
    train_and_save(padded, labels, model, 32, num_epochs, val)
# Out:
# Epoch 1/10
# 166/166 [==============================] - 11s 65ms/step - loss: 1.4838 - accuracy: 0.4963 - val_loss: 1.0584 - val_accuracy: 0.4574
# Epoch 2/10
# 166/166 [==============================] - 11s 64ms/step - loss: 0.9108 - accuracy: 0.6688 - val_loss: 0.9569 - val_accuracy: 0.5155
# Epoch 3/10
# 166/166 [==============================] - 11s 65ms/step - loss: 0.6490 - accuracy: 0.7739 - val_loss: 0.8015 - val_accuracy: 0.6491
# Epoch 4/10
# 166/166 [==============================] - 11s 65ms/step - loss: 0.5235 - accuracy: 0.8185 - val_loss: 0.8911 - val_accuracy: 0.6521
# Epoch 5/10
# 166/166 [==============================] - 11s 64ms/step - loss: 0.4674 - accuracy: 0.8417 - val_loss: 0.9132 - val_accuracy: 0.6989
# Epoch 6/10
# 166/166 [==============================] - 11s 65ms/step - loss: 0.4153 - accuracy: 0.8690 - val_loss: 1.0220 - val_accuracy: 0.6838
# Epoch 7/10
# 166/166 [==============================] - 11s 65ms/step - loss: 0.3966 - accuracy: 0.8704 - val_loss: 0.9484 - val_accuracy: 0.6860
# Epoch 8/10
# 166/166 [==============================] - 11s 64ms/step - loss: 0.3481 - accuracy: 0.8894 - val_loss: 0.9977 - val_accuracy: 0.7087
# Epoch 9/10
# 166/166 [==============================] - 11s 65ms/step - loss: 0.3085 - accuracy: 0.9004 - val_loss: 1.0799 - val_accuracy: 0.6860
# Epoch 10/10
# 166/166 [==============================] - 11s 65ms/step - loss: 0.3139 - accuracy: 0.9028 - val_loss: 1.1172 - val_accuracy: 0.6921
# Epoch 1/10
# 166/166 [==============================] - 11s 63ms/step - loss: 1.4935 - accuracy: 0.4542 - val_loss: 1.0371 - val_accuracy: 0.4574
# Epoch 2/10
# 166/166 [==============================] - 10s 62ms/step - loss: 0.8642 - accuracy: 0.6603 - val_loss: 0.9629 - val_accuracy: 0.4725
# Epoch 3/10
# 166/166 [==============================] - 10s 62ms/step - loss: 0.6201 - accuracy: 0.7628 - val_loss: 0.8298 - val_accuracy: 0.6249
# Epoch 4/10
# 166/166 [==============================] - 10s 62ms/step - loss: 0.4799 - accuracy: 0.8220 - val_loss: 0.8348 - val_accuracy: 0.6589
# Epoch 5/10
# 166/166 [==============================] - 10s 63ms/step - loss: 0.4202 - accuracy: 0.8462 - val_loss: 0.8217 - val_accuracy: 0.6838
# Epoch 6/10
# 166/166 [==============================] - 10s 62ms/step - loss: 0.3606 - accuracy: 0.8732 - val_loss: 0.8824 - val_accuracy: 0.6875
# Epoch 7/10
# 166/166 [==============================] - 10s 63ms/step - loss: 0.3293 - accuracy: 0.8849 - val_loss: 0.8540 - val_accuracy: 0.7042
# Epoch 8/10
# 166/166 [==============================] - 10s 63ms/step - loss: 0.3095 - accuracy: 0.8970 - val_loss: 0.8460 - val_accuracy: 0.7064
# Epoch 9/10
# 166/166 [==============================] - 10s 62ms/step - loss: 0.2680 - accuracy: 0.9134 - val_loss: 0.9052 - val_accuracy: 0.6996
# Epoch 10/10
# 166/166 [==============================] - 10s 63ms/step - loss: 0.2528 - accuracy: 0.9126 - val_loss: 0.9061 - val_accuracy: 0.6951
# Epoch 1/10
# 166/166 [==============================] - 11s 62ms/step - loss: 1.4256 - accuracy: 0.4463 - val_loss: 1.0259 - val_accuracy: 0.4574
# Epoch 2/10
# 166/166 [==============================] - 10s 61ms/step - loss: 0.9176 - accuracy: 0.6165 - val_loss: 0.9601 - val_accuracy: 0.4770
# Epoch 3/10
# 166/166 [==============================] - 10s 61ms/step - loss: 0.6371 - accuracy: 0.7430 - val_loss: 0.8386 - val_accuracy: 0.5675
# Epoch 4/10
# 166/166 [==============================] - 10s 62ms/step - loss: 0.4900 - accuracy: 0.8056 - val_loss: 0.7498 - val_accuracy: 0.6498
# Epoch 5/10
# 166/166 [==============================] - 11s 63ms/step - loss: 0.4129 - accuracy: 0.8477 - val_loss: 0.8024 - val_accuracy: 0.6830
# Epoch 6/10
# 166/166 [==============================] - 10s 63ms/step - loss: 0.3593 - accuracy: 0.8721 - val_loss: 0.8239 - val_accuracy: 0.7004
# Epoch 7/10
# 166/166 [==============================] - 10s 63ms/step - loss: 0.3063 - accuracy: 0.8917 - val_loss: 0.8970 - val_accuracy: 0.6951
# Epoch 8/10
# 166/166 [==============================] - 10s 63ms/step - loss: 0.2926 - accuracy: 0.8975 - val_loss: 0.8863 - val_accuracy: 0.6883
# Epoch 9/10
# 166/166 [==============================] - 10s 63ms/step - loss: 0.2744 - accuracy: 0.9039 - val_loss: 0.8881 - val_accuracy: 0.7011
# Epoch 10/10
# 166/166 [==============================] - 10s 63ms/step - loss: 0.2455 - accuracy: 0.9172 - val_loss: 0.8793 - val_accuracy: 0.7034
# Epoch 1/10
# 166/166 [==============================] - 11s 61ms/step - loss: 1.4673 - accuracy: 0.4465 - val_loss: 1.0228 - val_accuracy: 0.4574
# Epoch 2/10
# 166/166 [==============================] - 10s 61ms/step - loss: 0.9538 - accuracy: 0.6082 - val_loss: 0.9579 - val_accuracy: 0.4883
# Epoch 3/10
# 166/166 [==============================] - 10s 61ms/step - loss: 0.6883 - accuracy: 0.7071 - val_loss: 0.8279 - val_accuracy: 0.5992
# Epoch 4/10
# 166/166 [==============================] - 10s 61ms/step - loss: 0.5226 - accuracy: 0.7932 - val_loss: 0.7091 - val_accuracy: 0.6860
# Epoch 5/10
# 166/166 [==============================] - 10s 61ms/step - loss: 0.4094 - accuracy: 0.8402 - val_loss: 0.7315 - val_accuracy: 0.7140
# Epoch 6/10
# 166/166 [==============================] - 10s 61ms/step - loss: 0.3832 - accuracy: 0.8630 - val_loss: 0.7796 - val_accuracy: 0.7034
# Epoch 7/10
# 166/166 [==============================] - 10s 61ms/step - loss: 0.3229 - accuracy: 0.8839 - val_loss: 0.8556 - val_accuracy: 0.6958
# Epoch 8/10
# 166/166 [==============================] - 10s 61ms/step - loss: 0.2786 - accuracy: 0.9041 - val_loss: 0.8752 - val_accuracy: 0.7057
# Epoch 9/10
# 166/166 [==============================] - 10s 61ms/step - loss: 0.2765 - accuracy: 0.9053 - val_loss: 0.9083 - val_accuracy: 0.6966
# Epoch 10/10
# 166/166 [==============================] - 10s 61ms/step - loss: 0.2467 - accuracy: 0.9166 - val_loss: 0.9213 - val_accuracy: 0.7034
# Epoch 1/10
# 166/166 [==============================] - 11s 61ms/step - loss: 1.4967 - accuracy: 0.4216 - val_loss: 1.0077 - val_accuracy: 0.4943
# Epoch 2/10
# 166/166 [==============================] - 10s 60ms/step - loss: 0.9847 - accuracy: 0.5724 - val_loss: 0.9486 - val_accuracy: 0.5902
# Epoch 3/10
# 166/166 [==============================] - 10s 60ms/step - loss: 0.7316 - accuracy: 0.6845 - val_loss: 0.8180 - val_accuracy: 0.6317
# Epoch 4/10
# 166/166 [==============================] - 10s 60ms/step - loss: 0.5754 - accuracy: 0.7673 - val_loss: 0.7320 - val_accuracy: 0.6657
# Epoch 5/10
# 166/166 [==============================] - 10s 61ms/step - loss: 0.4679 - accuracy: 0.8135 - val_loss: 0.7761 - val_accuracy: 0.6845
# Epoch 6/10
# 166/166 [==============================] - 10s 61ms/step - loss: 0.4097 - accuracy: 0.8502 - val_loss: 0.7824 - val_accuracy: 0.6928
# Epoch 7/10
# 166/166 [==============================] - 10s 60ms/step - loss: 0.3449 - accuracy: 0.8751 - val_loss: 0.8491 - val_accuracy: 0.6981
# Epoch 8/10
# 166/166 [==============================] - 10s 60ms/step - loss: 0.3090 - accuracy: 0.8930 - val_loss: 0.8333 - val_accuracy: 0.7064
# Epoch 9/10
# 166/166 [==============================] - 10s 61ms/step - loss: 0.3114 - accuracy: 0.8943 - val_loss: 0.8177 - val_accuracy: 0.7042
# Epoch 10/10
# 166/166 [==============================] - 10s 62ms/step - loss: 0.2711 - accuracy: 0.9055 - val_loss: 0.8795 - val_accuracy: 0.6981

# %% [markdown]
# ### 3-layer CNN

# %%
vocab_size = len(tokenizer.word_index) + 1
embedding_size = 30
max_words = 500
cnn_units = [64*2**i for i in range(0,6)]
num_epochs = 1
val = 0.2

for i in range(0, 5):
    units = 2048 / 2**i
    name = 'three_layer_cnn' + f'_{int(units)}'
    print(name)

    model = Sequential(name=name)
    model.add(layers.Embedding(vocab_size, embedding_size, input_length=max_seq_length))
    model.add(layers.Conv1D(512, 3, padding='valid', activation='relu', strides=1))
    model.add(layers.GlobalMaxPooling1D())
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(units, activation='relu'))    
    model.add(layers.Dropout(0.5))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(units / 2, activation='relu'))    
    model.add(layers.Dropout(0.5))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(3, activation='softmax'))
    model.compile(loss = 'categorical_crossentropy', optimizer='adam',metrics = ['accuracy'])
    train_and_save(padded, labels, model, 32, num_epochs, val)
# Out:
# three_layer_cnn_2048
# 166/166 [==============================] - 13s 75ms/step - loss: 1.6433 - accuracy: 0.4252 - val_loss: 1.0542 - val_accuracy: 0.4838
# three_layer_cnn_1024
# 166/166 [==============================] - 12s 65ms/step - loss: 1.5936 - accuracy: 0.4101 - val_loss: 1.0432 - val_accuracy: 0.4574
# three_layer_cnn_512
# 166/166 [==============================] - 11s 62ms/step - loss: 1.5712 - accuracy: 0.3857 - val_loss: 1.0460 - val_accuracy: 0.4574
# three_layer_cnn_256
# 166/166 [==============================] - 11s 61ms/step - loss: 1.5668 - accuracy: 0.3859 - val_loss: 1.0236 - val_accuracy: 0.4574
# three_layer_cnn_128
# 166/166 [==============================] - 11s 61ms/step - loss: 1.6565 - accuracy: 0.3727 - val_loss: 1.0207 - val_accuracy: 0.4574

# %% [markdown]
# # Training with pretrained embeddings
#
# ### rusvectores

# %%
vocab_size = len(tokenizer.word_index) + 1
embedding_size = 300
max_words = 500
cnn_units = [64*2**i for i in range(0,6)]
num_epochs = 10
val = 0.2

path_to_model_file = "rusvectores/model.txt"

embeddings_index = {}
with open(path_to_model_file) as f:
    for line in f:
        word, coefs = line.split(maxsplit=1)
        coefs = np.fromstring(coefs, "f", sep=" ")
        embeddings_index[word.split('_')[0]] = coefs

print("Found %s word vectors." % len(embeddings_index))

#create a weight matrix for words in training docs
embedding_matrix = np.zeros((vocab_size, 300))
for word, i in tokenizer.word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

embedding_matrix.shape


for i in cnn_units:
    name= 'rusvectores_embedding' + f'_{int(i)}'

    model = Sequential(name=name)
    model.add(layers.Embedding(vocab_size, embedding_size,
                               weights=[embedding_matrix],
                               input_length=max_seq_length,
                               trainable=False))
    model.add(layers.Conv1D(i, 3, padding='valid', activation='relu', strides=1))
    model.add(layers.GlobalMaxPooling1D())
    model.add(layers.Dense(3, activation='softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    print(model.summary())

    train_and_save(padded, labels, model, 32, num_epochs, val)
# Out:
# Found 215876 word vectors.
# Model: "rusvectores_embedding_64"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_140 (Embedding)   (None, 500, 300)          11229900
#
#  conv1d_115 (Conv1D)         (None, 498, 64)           57664
#
#  global_max_pooling1d_113 (G  (None, 64)               0
#  lobalMaxPooling1D)
#
#  dense_202 (Dense)           (None, 3)                 195
#
# =================================================================
# Total params: 11,287,759
# Trainable params: 57,859
# Non-trainable params: 11,229,900
# _________________________________________________________________
# None
# Epoch 1/10
# 166/166 [==============================] - 6s 34ms/step - loss: 0.9069 - accuracy: 0.5635 - val_loss: 0.8219 - val_accuracy: 0.6000
# Epoch 2/10
# 166/166 [==============================] - 6s 34ms/step - loss: 0.6722 - accuracy: 0.7082 - val_loss: 0.7731 - val_accuracy: 0.6498
# Epoch 3/10
# 166/166 [==============================] - 6s 35ms/step - loss: 0.5721 - accuracy: 0.7681 - val_loss: 0.7785 - val_accuracy: 0.6340
# Epoch 4/10
# 166/166 [==============================] - 6s 35ms/step - loss: 0.4856 - accuracy: 0.8117 - val_loss: 0.7670 - val_accuracy: 0.6694
# Epoch 5/10
# 166/166 [==============================] - 6s 35ms/step - loss: 0.4244 - accuracy: 0.8390 - val_loss: 0.8456 - val_accuracy: 0.6174
# Epoch 6/10
# 166/166 [==============================] - 6s 35ms/step - loss: 0.3632 - accuracy: 0.8756 - val_loss: 0.8500 - val_accuracy: 0.6234
# Epoch 7/10
# 166/166 [==============================] - 6s 35ms/step - loss: 0.3214 - accuracy: 0.8879 - val_loss: 0.8933 - val_accuracy: 0.6257
# Epoch 8/10
# 166/166 [==============================] - 6s 36ms/step - loss: 0.2857 - accuracy: 0.9049 - val_loss: 0.8457 - val_accuracy: 0.6521
# Epoch 9/10
# 166/166 [==============================] - 6s 37ms/step - loss: 0.2643 - accuracy: 0.9128 - val_loss: 0.8756 - val_accuracy: 0.6483
# Epoch 10/10
# 166/166 [==============================] - 6s 37ms/step - loss: 0.2393 - accuracy: 0.9158 - val_loss: 0.8867 - val_accuracy: 0.6558
# Model: "rusvectores_embedding_128"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_141 (Embedding)   (None, 500, 300)          11229900
#
#  conv1d_116 (Conv1D)         (None, 498, 128)          115328
#
#  global_max_pooling1d_114 (G  (None, 128)              0
#  lobalMaxPooling1D)
#
#  dense_203 (Dense)           (None, 3)                 387
#
# =================================================================
# Total params: 11,345,615
# Trainable params: 115,715
# Non-trainable params: 11,229,900
# _________________________________________________________________
# None
# Epoch 1/10
# 166/166 [==============================] - 8s 48ms/step - loss: 0.8660 - accuracy: 0.5877 - val_loss: 0.8416 - val_accuracy: 0.5902
# Epoch 2/10
# 166/166 [==============================] - 8s 48ms/step - loss: 0.6200 - accuracy: 0.7341 - val_loss: 0.7746 - val_accuracy: 0.6438
# Epoch 3/10
# 166/166 [==============================] - 8s 51ms/step - loss: 0.4918 - accuracy: 0.8064 - val_loss: 0.7685 - val_accuracy: 0.6536
# Epoch 4/10
# 166/166 [==============================] - 9s 53ms/step - loss: 0.4032 - accuracy: 0.8571 - val_loss: 0.8065 - val_accuracy: 0.6468
# Epoch 5/10
# 166/166 [==============================] - 9s 52ms/step - loss: 0.3430 - accuracy: 0.8781 - val_loss: 0.8147 - val_accuracy: 0.6543
# Epoch 6/10
# 166/166 [==============================] - 9s 52ms/step - loss: 0.3000 - accuracy: 0.9021 - val_loss: 0.8421 - val_accuracy: 0.6438
# Epoch 7/10
# 166/166 [==============================] - 9s 52ms/step - loss: 0.2716 - accuracy: 0.9068 - val_loss: 0.8715 - val_accuracy: 0.6543
# Epoch 8/10
# 166/166 [==============================] - 9s 52ms/step - loss: 0.2464 - accuracy: 0.9200 - val_loss: 0.9962 - val_accuracy: 0.6098
# Epoch 9/10
# 166/166 [==============================] - 9s 52ms/step - loss: 0.2321 - accuracy: 0.9204 - val_loss: 0.9467 - val_accuracy: 0.6521
# Epoch 10/10
# 166/166 [==============================] - 9s 53ms/step - loss: 0.2326 - accuracy: 0.9209 - val_loss: 1.0364 - val_accuracy: 0.6249
# Model: "rusvectores_embedding_256"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_142 (Embedding)   (None, 500, 300)          11229900
#
#  conv1d_117 (Conv1D)         (None, 498, 256)          230656
#
#  global_max_pooling1d_115 (G  (None, 256)              0
#  lobalMaxPooling1D)
#
#  dense_204 (Dense)           (None, 3)                 771
#
# =================================================================
# Total params: 11,461,327
# Trainable params: 231,427
# Non-trainable params: 11,229,900
# _________________________________________________________________
# None
# Epoch 1/10
# 166/166 [==============================] - 14s 82ms/step - loss: 0.8788 - accuracy: 0.5875 - val_loss: 0.7665 - val_accuracy: 0.6581
# Epoch 2/10
# 166/166 [==============================] - 14s 86ms/step - loss: 0.5801 - accuracy: 0.7569 - val_loss: 0.8082 - val_accuracy: 0.6143
# Epoch 3/10
# 166/166 [==============================] - 15s 88ms/step - loss: 0.4571 - accuracy: 0.8241 - val_loss: 0.7790 - val_accuracy: 0.6543
# Epoch 4/10
# 166/166 [==============================] - 15s 89ms/step - loss: 0.3859 - accuracy: 0.8600 - val_loss: 0.8050 - val_accuracy: 0.6400
# Epoch 5/10
# 166/166 [==============================] - 15s 89ms/step - loss: 0.3049 - accuracy: 0.8949 - val_loss: 0.8610 - val_accuracy: 0.6528
# Epoch 6/10
# 166/166 [==============================] - 14s 87ms/step - loss: 0.2923 - accuracy: 0.9038 - val_loss: 0.8682 - val_accuracy: 0.6392
# Epoch 7/10
# 166/166 [==============================] - 14s 87ms/step - loss: 0.2759 - accuracy: 0.9068 - val_loss: 0.9717 - val_accuracy: 0.6204
# Epoch 8/10
# 166/166 [==============================] - 15s 88ms/step - loss: 0.2505 - accuracy: 0.9143 - val_loss: 0.9886 - val_accuracy: 0.6408
# Epoch 9/10
# 166/166 [==============================] - 15s 88ms/step - loss: 0.2283 - accuracy: 0.9247 - val_loss: 0.9945 - val_accuracy: 0.6415
# Epoch 10/10
# 166/166 [==============================] - 14s 86ms/step - loss: 0.2349 - accuracy: 0.9217 - val_loss: 1.0841 - val_accuracy: 0.6400
# Model: "rusvectores_embedding_512"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_143 (Embedding)   (None, 500, 300)          11229900
#
#  conv1d_118 (Conv1D)         (None, 498, 512)          461312
#
#  global_max_pooling1d_116 (G  (None, 512)              0
#  lobalMaxPooling1D)
#
#  dense_205 (Dense)           (None, 3)                 1539
#
# =================================================================
# Total params: 11,692,751
# Trainable params: 462,851
# Non-trainable params: 11,229,900
# _________________________________________________________________
# None
# Epoch 1/10
# 166/166 [==============================] - 25s 149ms/step - loss: 0.8733 - accuracy: 0.5994 - val_loss: 0.7927 - val_accuracy: 0.6347
# Epoch 2/10
# 166/166 [==============================] - 25s 153ms/step - loss: 0.5538 - accuracy: 0.7724 - val_loss: 0.8650 - val_accuracy: 0.6468
# Epoch 3/10
# 166/166 [==============================] - 25s 152ms/step - loss: 0.4417 - accuracy: 0.8281 - val_loss: 0.8205 - val_accuracy: 0.6596
# Epoch 4/10
# 166/166 [==============================] - 26s 159ms/step - loss: 0.3497 - accuracy: 0.8726 - val_loss: 0.8750 - val_accuracy: 0.6551
# Epoch 5/10
# 166/166 [==============================] - 26s 158ms/step - loss: 0.2957 - accuracy: 0.9024 - val_loss: 0.9180 - val_accuracy: 0.6589
# Epoch 6/10
# 166/166 [==============================] - 26s 157ms/step - loss: 0.2996 - accuracy: 0.9017 - val_loss: 0.9698 - val_accuracy: 0.6483
# Epoch 7/10
# 166/166 [==============================] - 26s 158ms/step - loss: 0.2824 - accuracy: 0.9049 - val_loss: 0.9855 - val_accuracy: 0.6551
# Epoch 8/10
# 166/166 [==============================] - 26s 157ms/step - loss: 0.2678 - accuracy: 0.9136 - val_loss: 1.0045 - val_accuracy: 0.6657
# Epoch 9/10
# 166/166 [==============================] - 26s 157ms/step - loss: 0.2393 - accuracy: 0.9245 - val_loss: 1.0381 - val_accuracy: 0.6483
# Epoch 10/10
# 166/166 [==============================] - 27s 165ms/step - loss: 0.2463 - accuracy: 0.9253 - val_loss: 1.1101 - val_accuracy: 0.6460
# Model: "rusvectores_embedding_1024"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_144 (Embedding)   (None, 500, 300)          11229900
#
#  conv1d_119 (Conv1D)         (None, 498, 1024)         922624
#
#  global_max_pooling1d_117 (G  (None, 1024)             0
#  lobalMaxPooling1D)
#
#  dense_206 (Dense)           (None, 3)                 3075
#
# =================================================================
# Total params: 12,155,599
# Trainable params: 925,699
# Non-trainable params: 11,229,900
# _________________________________________________________________
# None
# Epoch 1/10
# 166/166 [==============================] - 49s 295ms/step - loss: 0.9040 - accuracy: 0.5978 - val_loss: 0.7913 - val_accuracy: 0.6506
# Epoch 2/10
# 166/166 [==============================] - 50s 302ms/step - loss: 0.5580 - accuracy: 0.7709 - val_loss: 0.8950 - val_accuracy: 0.6242
# Epoch 3/10
# 166/166 [==============================] - 49s 293ms/step - loss: 0.4386 - accuracy: 0.8305 - val_loss: 0.8406 - val_accuracy: 0.6747
# Epoch 4/10
# 166/166 [==============================] - 50s 300ms/step - loss: 0.3639 - accuracy: 0.8685 - val_loss: 0.8919 - val_accuracy: 0.6657
# Epoch 5/10
# 166/166 [==============================] - 50s 300ms/step - loss: 0.3294 - accuracy: 0.8926 - val_loss: 1.2078 - val_accuracy: 0.6015
# Epoch 6/10
# 166/166 [==============================] - 50s 302ms/step - loss: 0.3456 - accuracy: 0.8815 - val_loss: 0.9710 - val_accuracy: 0.6725
# Epoch 7/10
# 166/166 [==============================] - 50s 303ms/step - loss: 0.3088 - accuracy: 0.8981 - val_loss: 1.3704 - val_accuracy: 0.6038
# Epoch 8/10
# 166/166 [==============================] - 49s 293ms/step - loss: 0.2826 - accuracy: 0.9083 - val_loss: 1.0453 - val_accuracy: 0.6475
# Epoch 9/10
# 166/166 [==============================] - 49s 294ms/step - loss: 0.2782 - accuracy: 0.9111 - val_loss: 1.0893 - val_accuracy: 0.6332
# Epoch 10/10
# 166/166 [==============================] - 49s 295ms/step - loss: 0.2752 - accuracy: 0.9109 - val_loss: 1.3350 - val_accuracy: 0.6355
# Model: "rusvectores_embedding_2048"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_145 (Embedding)   (None, 500, 300)          11229900
#
#  conv1d_120 (Conv1D)         (None, 498, 2048)         1845248
#
#  global_max_pooling1d_118 (G  (None, 2048)             0
#  lobalMaxPooling1D)
#
#  dense_207 (Dense)           (None, 3)                 6147
#
# =================================================================
# Total params: 13,081,295
# Trainable params: 1,851,395
# Non-trainable params: 11,229,900
# _________________________________________________________________
# None
# Epoch 1/10
# 166/166 [==============================] - 102s 614ms/step - loss: 0.9573 - accuracy: 0.5839 - val_loss: 0.7895 - val_accuracy: 0.6483
# Epoch 2/10
# 166/166 [==============================] - 103s 618ms/step - loss: 0.5892 - accuracy: 0.7552 - val_loss: 0.8238 - val_accuracy: 0.6415
# Epoch 3/10
# 166/166 [==============================] - 102s 613ms/step - loss: 0.4694 - accuracy: 0.8220 - val_loss: 0.8788 - val_accuracy: 0.6438
# Epoch 4/10
# 166/166 [==============================] - 103s 619ms/step - loss: 0.3767 - accuracy: 0.8581 - val_loss: 0.9236 - val_accuracy: 0.6423
# Epoch 5/10
# 166/166 [==============================] - 102s 613ms/step - loss: 0.3536 - accuracy: 0.8800 - val_loss: 1.0538 - val_accuracy: 0.6506
# Epoch 6/10
# 166/166 [==============================] - 102s 616ms/step - loss: 0.3096 - accuracy: 0.8973 - val_loss: 1.1641 - val_accuracy: 0.5947
# Epoch 7/10
# 166/166 [==============================] - 101s 611ms/step - loss: 0.3431 - accuracy: 0.8838 - val_loss: 1.1050 - val_accuracy: 0.6453
# Epoch 8/10
# 166/166 [==============================] - 103s 618ms/step - loss: 0.3105 - accuracy: 0.9051 - val_loss: 1.0811 - val_accuracy: 0.6408
# Epoch 9/10
# 166/166 [==============================] - 102s 617ms/step - loss: 0.2792 - accuracy: 0.9155 - val_loss: 1.1617 - val_accuracy: 0.6483
# Epoch 10/10
# 166/166 [==============================] - 102s 615ms/step - loss: 0.2714 - accuracy: 0.9139 - val_loss: 1.1102 - val_accuracy: 0.6491

# %% [markdown]
# ### Training the same model with embedding layer to compare

# %%
vocab_size = len(tokenizer.word_index) + 1
embedding_size = 300
max_words = 500
cnn_units = [64*2**i for i in range(0,6)]
num_epochs = 10
val = 0.2

for i in cnn_units:
    name= 'embeddings_base' + f'_{int(i)}'

    model = Sequential(name=name)
    model.add(layers.Embedding(vocab_size, embedding_size,
                               input_length=max_seq_length))
    model.add(layers.Conv1D(i, 3, padding='valid', activation='relu', strides=1))
    model.add(layers.GlobalMaxPooling1D())
    model.add(layers.Dense(3, activation='softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    print(model.summary())

    train_and_save(padded, labels, model, 32, num_epochs, val)
# Out:
# Model: "embeddings_base_64"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_146 (Embedding)   (None, 500, 300)          11229900
#
#  conv1d_121 (Conv1D)         (None, 498, 64)           57664
#
#  global_max_pooling1d_119 (G  (None, 64)               0
#  lobalMaxPooling1D)
#
#  dense_208 (Dense)           (None, 3)                 195
#
# =================================================================
# Total params: 11,287,759
# Trainable params: 11,287,759
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 166/166 [==============================] - 21s 122ms/step - loss: 0.8590 - accuracy: 0.6018 - val_loss: 0.7278 - val_accuracy: 0.6664
# Epoch 2/10
# 166/166 [==============================] - 20s 121ms/step - loss: 0.5160 - accuracy: 0.8066 - val_loss: 0.6714 - val_accuracy: 0.7109
# Epoch 3/10
# 166/166 [==============================] - 20s 120ms/step - loss: 0.3095 - accuracy: 0.8922 - val_loss: 0.7144 - val_accuracy: 0.7102
# Epoch 4/10
# 166/166 [==============================] - 20s 121ms/step - loss: 0.2236 - accuracy: 0.9196 - val_loss: 0.7698 - val_accuracy: 0.7079
# Epoch 5/10
# 166/166 [==============================] - 20s 121ms/step - loss: 0.1974 - accuracy: 0.9294 - val_loss: 0.7953 - val_accuracy: 0.7094
# Epoch 6/10
# 166/166 [==============================] - 20s 120ms/step - loss: 0.1773 - accuracy: 0.9324 - val_loss: 0.8164 - val_accuracy: 0.7155
# Epoch 7/10
# 166/166 [==============================] - 20s 120ms/step - loss: 0.1697 - accuracy: 0.9349 - val_loss: 0.8397 - val_accuracy: 0.7102
# Epoch 8/10
# 166/166 [==============================] - 20s 121ms/step - loss: 0.1543 - accuracy: 0.9426 - val_loss: 0.8692 - val_accuracy: 0.7049
# Epoch 9/10
# 166/166 [==============================] - 20s 120ms/step - loss: 0.1584 - accuracy: 0.9430 - val_loss: 0.8669 - val_accuracy: 0.7072
# Epoch 10/10
# 166/166 [==============================] - 20s 121ms/step - loss: 0.1449 - accuracy: 0.9430 - val_loss: 0.8725 - val_accuracy: 0.7072
# Model: "embeddings_base_128"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_147 (Embedding)   (None, 500, 300)          11229900
#
#  conv1d_122 (Conv1D)         (None, 498, 128)          115328
#
#  global_max_pooling1d_120 (G  (None, 128)              0
#  lobalMaxPooling1D)
#
#  dense_209 (Dense)           (None, 3)                 387
#
# =================================================================
# Total params: 11,345,615
# Trainable params: 11,345,615
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 166/166 [==============================] - 23s 138ms/step - loss: 0.8340 - accuracy: 0.6118 - val_loss: 0.7064 - val_accuracy: 0.6808
# Epoch 2/10
# 166/166 [==============================] - 23s 137ms/step - loss: 0.4921 - accuracy: 0.8105 - val_loss: 0.6436 - val_accuracy: 0.7268
# Epoch 3/10
# 166/166 [==============================] - 23s 137ms/step - loss: 0.2955 - accuracy: 0.8958 - val_loss: 0.7124 - val_accuracy: 0.7223
# Epoch 4/10
# 166/166 [==============================] - 23s 137ms/step - loss: 0.2207 - accuracy: 0.9189 - val_loss: 0.7933 - val_accuracy: 0.7064
# Epoch 5/10
# 166/166 [==============================] - 23s 141ms/step - loss: 0.1930 - accuracy: 0.9277 - val_loss: 0.7642 - val_accuracy: 0.7140
# Epoch 6/10
# 166/166 [==============================] - 23s 138ms/step - loss: 0.1813 - accuracy: 0.9332 - val_loss: 0.8083 - val_accuracy: 0.7140
# Epoch 7/10
# 166/166 [==============================] - 23s 139ms/step - loss: 0.1645 - accuracy: 0.9392 - val_loss: 0.8458 - val_accuracy: 0.6989
# Epoch 8/10
# 166/166 [==============================] - 23s 139ms/step - loss: 0.1539 - accuracy: 0.9445 - val_loss: 0.8359 - val_accuracy: 0.7109
# Epoch 9/10
# 166/166 [==============================] - 23s 137ms/step - loss: 0.1541 - accuracy: 0.9443 - val_loss: 0.8284 - val_accuracy: 0.7162
# Epoch 10/10
# 166/166 [==============================] - 23s 139ms/step - loss: 0.1386 - accuracy: 0.9468 - val_loss: 0.8522 - val_accuracy: 0.7094
# Model: "embeddings_base_256"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_148 (Embedding)   (None, 500, 300)          11229900
#
#  conv1d_123 (Conv1D)         (None, 498, 256)          230656
#
#  global_max_pooling1d_121 (G  (None, 256)              0
#  lobalMaxPooling1D)
#
#  dense_210 (Dense)           (None, 3)                 771
#
# =================================================================
# Total params: 11,461,327
# Trainable params: 11,461,327
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 166/166 [==============================] - 30s 178ms/step - loss: 0.8325 - accuracy: 0.6201 - val_loss: 0.6914 - val_accuracy: 0.6883
# Epoch 2/10
# 166/166 [==============================] - 30s 183ms/step - loss: 0.4889 - accuracy: 0.8094 - val_loss: 0.6417 - val_accuracy: 0.7291
# Epoch 3/10
# 166/166 [==============================] - 30s 183ms/step - loss: 0.2874 - accuracy: 0.8953 - val_loss: 0.7071 - val_accuracy: 0.7291
# Epoch 4/10
# 166/166 [==============================] - 30s 182ms/step - loss: 0.2217 - accuracy: 0.9204 - val_loss: 0.7479 - val_accuracy: 0.7026
# Epoch 5/10
# 166/166 [==============================] - 30s 182ms/step - loss: 0.1861 - accuracy: 0.9300 - val_loss: 0.7902 - val_accuracy: 0.7140
# Epoch 6/10
# 166/166 [==============================] - 30s 182ms/step - loss: 0.1787 - accuracy: 0.9375 - val_loss: 0.8296 - val_accuracy: 0.7192
# Epoch 7/10
# 166/166 [==============================] - 29s 176ms/step - loss: 0.1597 - accuracy: 0.9432 - val_loss: 0.8197 - val_accuracy: 0.7253
# Epoch 8/10
# 166/166 [==============================] - 30s 179ms/step - loss: 0.1526 - accuracy: 0.9457 - val_loss: 0.8531 - val_accuracy: 0.7087
# Epoch 9/10
# 166/166 [==============================] - 30s 182ms/step - loss: 0.1477 - accuracy: 0.9470 - val_loss: 0.9533 - val_accuracy: 0.6906
# Epoch 10/10
# 166/166 [==============================] - 30s 181ms/step - loss: 0.1335 - accuracy: 0.9519 - val_loss: 0.8763 - val_accuracy: 0.7125
# Model: "embeddings_base_512"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_149 (Embedding)   (None, 500, 300)          11229900
#
#  conv1d_124 (Conv1D)         (None, 498, 512)          461312
#
#  global_max_pooling1d_122 (G  (None, 512)              0
#  lobalMaxPooling1D)
#
#  dense_211 (Dense)           (None, 3)                 1539
#
# =================================================================
# Total params: 11,692,751
# Trainable params: 11,692,751
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 166/166 [==============================] - 46s 273ms/step - loss: 0.8306 - accuracy: 0.6069 - val_loss: 0.6914 - val_accuracy: 0.6830
# Epoch 2/10
# 166/166 [==============================] - 47s 284ms/step - loss: 0.4906 - accuracy: 0.8077 - val_loss: 0.6512 - val_accuracy: 0.7238
# Epoch 3/10
# 166/166 [==============================] - 47s 283ms/step - loss: 0.2913 - accuracy: 0.8921 - val_loss: 0.7093 - val_accuracy: 0.7117
# Epoch 4/10
# 166/166 [==============================] - 45s 273ms/step - loss: 0.2241 - accuracy: 0.9189 - val_loss: 0.7685 - val_accuracy: 0.7215
# Epoch 5/10
# 166/166 [==============================] - 46s 274ms/step - loss: 0.1977 - accuracy: 0.9281 - val_loss: 0.8079 - val_accuracy: 0.7162
# Epoch 6/10
# 166/166 [==============================] - 47s 284ms/step - loss: 0.1727 - accuracy: 0.9392 - val_loss: 0.8345 - val_accuracy: 0.7245
# Epoch 7/10
# 166/166 [==============================] - 47s 285ms/step - loss: 0.1641 - accuracy: 0.9394 - val_loss: 0.8489 - val_accuracy: 0.7079
# Epoch 8/10
# 166/166 [==============================] - 47s 284ms/step - loss: 0.1501 - accuracy: 0.9473 - val_loss: 0.9038 - val_accuracy: 0.7162
# Epoch 9/10
# 166/166 [==============================] - 47s 281ms/step - loss: 0.1519 - accuracy: 0.9460 - val_loss: 0.9323 - val_accuracy: 0.7057
# Epoch 10/10
# 166/166 [==============================] - 48s 292ms/step - loss: 0.1291 - accuracy: 0.9519 - val_loss: 0.9491 - val_accuracy: 0.7102
# Model: "embeddings_base_1024"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_150 (Embedding)   (None, 500, 300)          11229900
#
#  conv1d_125 (Conv1D)         (None, 498, 1024)         922624
#
#  global_max_pooling1d_123 (G  (None, 1024)             0
#  lobalMaxPooling1D)
#
#  dense_212 (Dense)           (None, 3)                 3075
#
# =================================================================
# Total params: 12,155,599
# Trainable params: 12,155,599
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 166/166 [==============================] - 81s 485ms/step - loss: 0.8096 - accuracy: 0.6156 - val_loss: 0.6676 - val_accuracy: 0.7042
# Epoch 2/10
# 166/166 [==============================] - 80s 482ms/step - loss: 0.4829 - accuracy: 0.8079 - val_loss: 0.6510 - val_accuracy: 0.7298
# Epoch 3/10
# 166/166 [==============================] - 80s 480ms/step - loss: 0.2827 - accuracy: 0.8956 - val_loss: 0.7524 - val_accuracy: 0.7125
# Epoch 4/10
# 166/166 [==============================] - 81s 486ms/step - loss: 0.2162 - accuracy: 0.9232 - val_loss: 0.8345 - val_accuracy: 0.7094
# Epoch 5/10
# 166/166 [==============================] - 82s 492ms/step - loss: 0.1969 - accuracy: 0.9272 - val_loss: 0.8911 - val_accuracy: 0.7109
# Epoch 6/10
# 166/166 [==============================] - 80s 483ms/step - loss: 0.1789 - accuracy: 0.9398 - val_loss: 1.0024 - val_accuracy: 0.6951
# Epoch 7/10
# 166/166 [==============================] - 80s 481ms/step - loss: 0.1570 - accuracy: 0.9451 - val_loss: 0.9292 - val_accuracy: 0.7094
# Epoch 8/10
# 166/166 [==============================] - 79s 473ms/step - loss: 0.1445 - accuracy: 0.9470 - val_loss: 0.9767 - val_accuracy: 0.6996
# Epoch 9/10
# 166/166 [==============================] - 81s 487ms/step - loss: 0.1348 - accuracy: 0.9494 - val_loss: 1.0330 - val_accuracy: 0.6943
# Epoch 10/10
# 166/166 [==============================] - 80s 479ms/step - loss: 0.1249 - accuracy: 0.9517 - val_loss: 1.0775 - val_accuracy: 0.6958
# Model: "embeddings_base_2048"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_151 (Embedding)   (None, 500, 300)          11229900
#
#  conv1d_126 (Conv1D)         (None, 498, 2048)         1845248
#
#  global_max_pooling1d_124 (G  (None, 2048)             0
#  lobalMaxPooling1D)
#
#  dense_213 (Dense)           (None, 3)                 6147
#
# =================================================================
# Total params: 13,081,295
# Trainable params: 13,081,295
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 166/166 [==============================] - 154s 927ms/step - loss: 0.7940 - accuracy: 0.6224 - val_loss: 0.6636 - val_accuracy: 0.7057
# Epoch 2/10
# 166/166 [==============================] - 155s 934ms/step - loss: 0.4697 - accuracy: 0.8083 - val_loss: 0.6793 - val_accuracy: 0.7125
# Epoch 3/10
# 166/166 [==============================] - 156s 941ms/step - loss: 0.2997 - accuracy: 0.8930 - val_loss: 0.8333 - val_accuracy: 0.6981
# Epoch 4/10
# 166/166 [==============================] - 155s 936ms/step - loss: 0.2284 - accuracy: 0.9202 - val_loss: 0.9068 - val_accuracy: 0.6989
# Epoch 5/10
# 166/166 [==============================] - 154s 928ms/step - loss: 0.1900 - accuracy: 0.9345 - val_loss: 0.9283 - val_accuracy: 0.7034
# Epoch 6/10
# 166/166 [==============================] - 155s 931ms/step - loss: 0.1740 - accuracy: 0.9389 - val_loss: 1.0932 - val_accuracy: 0.6732
# Epoch 7/10
# 166/166 [==============================] - 155s 933ms/step - loss: 0.1507 - accuracy: 0.9443 - val_loss: 1.0077 - val_accuracy: 0.7125
# Epoch 8/10
# 166/166 [==============================] - 158s 951ms/step - loss: 0.1379 - accuracy: 0.9487 - val_loss: 1.1236 - val_accuracy: 0.6906
# Epoch 9/10
# 166/166 [==============================] - 155s 933ms/step - loss: 0.1306 - accuracy: 0.9513 - val_loss: 1.0954 - val_accuracy: 0.6898
# Epoch 10/10
# 166/166 [==============================] - 155s 935ms/step - loss: 0.1305 - accuracy: 0.9504 - val_loss: 1.1268 - val_accuracy: 0.6943

# %% [markdown]
# # Hyperparameter optimisation

# %%
import keras_tuner as kt

def build_model(hp, name='test'):
    model = Sequential(name=name)
    model.add(layers.Embedding(vocab_size, embedding_size,
                               input_length=max_seq_length))
    model.add(layers.Conv1D(filters=hp.Choice('filters', [64*2**i for i in range(0,6)]),
                            activation='relu',
                            kernel_size=hp.Choice('kernel_size', [3, 5, 10]),
                            padding='valid',
                            strides=1))
    model.add(layers.GlobalMaxPooling1D())
    model.add(layers.Dense(3, activation='softmax'))

    model.compile(optimizer=hp.Choice('optimizer', ['adam', 'rmsprop']),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

tuner = kt.BayesianOptimization(
    build_model,
    objective='val_loss',
    max_trials=20
)

tuner.search(padded, labels, epochs=10, validation_split=0.2)
best_model = tuner.get_best_models()[0]
# Out:
# Trial 20 Complete [00h 03m 06s]
# val_loss: 0.6591543555259705
#
# Best val_loss So Far: 0.6429233551025391
# Total elapsed time: 00h 51m 44s
# INFO:tensorflow:Oracle triggered exit
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate

# %%
best_hps = tuner.get_best_hyperparameters(5)

best_optimizer = best_hps[0].get('optimizer')
best_filters = best_hps[0].get('filters')
best_kernel_size = best_hps[0].get('kernel_size')

print(f"Best optimizer: {best_optimizer}")
print(f"Best filters: {best_filters}")
print(f"Best kernel size: {best_kernel_size}")
# Out:
# Best optimizer: adam
# Best filters: 256
# Best kernel size: 10

# %%
model = build_model(best_hps[0], 'best_model')


train_and_save(padded, labels, model, 32, 20, val)
# Out:
# Epoch 1/20
# 166/166 [==============================] - 9s 54ms/step - loss: 0.9289 - accuracy: 0.5560 - val_loss: 0.7324 - val_accuracy: 0.6528
# Epoch 2/20
# 166/166 [==============================] - 9s 54ms/step - loss: 0.5785 - accuracy: 0.7541 - val_loss: 0.6700 - val_accuracy: 0.7132
# Epoch 3/20
# 166/166 [==============================] - 9s 55ms/step - loss: 0.3522 - accuracy: 0.8671 - val_loss: 0.7303 - val_accuracy: 0.7102
# Epoch 4/20
# 166/166 [==============================] - 9s 56ms/step - loss: 0.2338 - accuracy: 0.9096 - val_loss: 0.8436 - val_accuracy: 0.6996
# Epoch 5/20
# 166/166 [==============================] - 9s 57ms/step - loss: 0.1883 - accuracy: 0.9222 - val_loss: 0.8804 - val_accuracy: 0.7026
# Epoch 6/20
# 166/166 [==============================] - 10s 58ms/step - loss: 0.1641 - accuracy: 0.9294 - val_loss: 0.9140 - val_accuracy: 0.7004
# Epoch 7/20
# 166/166 [==============================] - 10s 59ms/step - loss: 0.1492 - accuracy: 0.9343 - val_loss: 0.9413 - val_accuracy: 0.7094
# Epoch 8/20
# 166/166 [==============================] - 10s 57ms/step - loss: 0.1345 - accuracy: 0.9409 - val_loss: 0.9690 - val_accuracy: 0.7026
# Epoch 9/20
# 166/166 [==============================] - 10s 61ms/step - loss: 0.1291 - accuracy: 0.9407 - val_loss: 1.0495 - val_accuracy: 0.6898
# Epoch 10/20
# 166/166 [==============================] - 9s 57ms/step - loss: 0.1236 - accuracy: 0.9436 - val_loss: 1.0158 - val_accuracy: 0.7072
# Epoch 11/20
# 166/166 [==============================] - 10s 58ms/step - loss: 0.1135 - accuracy: 0.9483 - val_loss: 1.0315 - val_accuracy: 0.7042
# Epoch 12/20
# 166/166 [==============================] - 9s 57ms/step - loss: 0.1098 - accuracy: 0.9492 - val_loss: 1.0615 - val_accuracy: 0.7004
# Epoch 13/20
# 166/166 [==============================] - 10s 58ms/step - loss: 0.1051 - accuracy: 0.9483 - val_loss: 1.0882 - val_accuracy: 0.7004
# Epoch 14/20
# 166/166 [==============================] - 10s 58ms/step - loss: 0.1016 - accuracy: 0.9521 - val_loss: 1.1114 - val_accuracy: 0.6966
# Epoch 15/20
# 166/166 [==============================] - 10s 58ms/step - loss: 0.0984 - accuracy: 0.9540 - val_loss: 1.0902 - val_accuracy: 0.6981
# Epoch 16/20
# 166/166 [==============================] - 10s 58ms/step - loss: 0.0930 - accuracy: 0.9534 - val_loss: 1.1255 - val_accuracy: 0.6943
# Epoch 17/20
# 166/166 [==============================] - 10s 58ms/step - loss: 0.0946 - accuracy: 0.9557 - val_loss: 1.2157 - val_accuracy: 0.6792
# Epoch 18/20
# 166/166 [==============================] - 10s 61ms/step - loss: 0.0931 - accuracy: 0.9555 - val_loss: 1.1943 - val_accuracy: 0.6830
# Epoch 19/20
# 166/166 [==============================] - 10s 58ms/step - loss: 0.0920 - accuracy: 0.9540 - val_loss: 1.1674 - val_accuracy: 0.6943
# Epoch 20/20
# 166/166 [==============================] - 10s 57ms/step - loss: 0.0849 - accuracy: 0.9572 - val_loss: 1.1799 - val_accuracy: 0.6928

# %% [markdown]
# ## RNN

# %%
vocab_size = len(tokenizer.word_index) + 1
embedding_size = 30
max_words = 500
rnn_units = [500, 500]
num_epochs = 10
val = 0.2
opt = keras.optimizers.RMSprop(learning_rate=0.0001)
print(rnn_units)

for i in rnn_units:
    
    name = 'base_lstm' + f'_{int(i)}'
    
    model = Sequential(name=name)
    model.add(layers.Embedding(vocab_size, embedding_size,
                               input_length=max_seq_length))
#     model.add(layers.LSTM(rnn_units, activation = 'relu', return_sequences=True))
#     model.add(layers.Dropout(0.2))
    model.add(layers.ConvLSTM1D(i, kernel_size=10, activation = 'relu'))
    #model.add(layers.Dropout(0.2))
    model.add(layers.Dense(50,activation='relu'))
    model.add(layers.Dense(3, activation='softmax'))
    model.compile(loss = 'categorical_crossentropy', optimizer=opt, metrics = ['accuracy'])
    
    train_and_save(padded, labels, model, 256, num_epochs, val)
# Out:
# [500, 500]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [344], in <cell line: 10>()
#      15     model.add(layers.Embedding(vocab_size, embedding_size,
#      16                                input_length=max_seq_length))
#      17 #     model.add(layers.LSTM(rnn_units, activation = 'relu', return_sequences=True))
#      18 #     model.add(layers.Dropout(0.2))
# ---> 19     model.add(layers.ConvLSTM1D(i, kernel_size=10, activation = 'relu'))
#      20     #model.add(layers.Dropout(0.2))
#      21     model.add(layers.Dense(50,activation='relu'))
#
# File ~/miniconda3/envs/ukraine/lib/python3.10/site-packages/tensorflow/python/training/tracking/base.py:629, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     627 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     628 try:
# --> 629   result = method(self, *args, **kwargs)
#     630 finally:
#     631   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~/miniconda3/envs/ukraine/lib/python3.10/site-packages/keras/utils/traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~/miniconda3/envs/ukraine/lib/python3.10/site-packages/keras/engine/input_spec.py:214, in assert_input_compatibility(input_spec, inputs, layer_name)
#     212   ndim = shape.rank
#     213   if ndim != spec.ndim:
# --> 214     raise ValueError(f'Input {input_index} of layer "{layer_name}" '
#     215                      'is incompatible with the layer: '
#     216                      f'expected ndim={spec.ndim}, found ndim={ndim}. '
#     217                      f'Full shape received: {tuple(shape)}')
#     218 if spec.max_ndim is not None:
#     219   ndim = x.shape.rank
#
# ValueError: Input 0 of layer "conv_lstm1d" is incompatible with the layer: expected ndim=4, found ndim=3. Full shape received: (None, 500, 30)

# %%
vocab_size = len(tokenizer.word_index) + 1
embedding_size = 30
max_words = 500
rnn_units = [64*2**i for i in range(0,6)]
num_epochs = 10
val = 0.2

print(rnn_units)

for i in rnn_units:
    
    name = 'bidirectional_lstm' + f'_{int(i)}'
    
    model = Sequential(name=name)
    model.add(layers.Embedding(vocab_size, embedding_size, input_length=max_seq_length))
    model.add(layers.Bidirectional(layers.LSTM(i)))
    model.add(layers.Dropout(0.5))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(3, activation='softmax'))
    model.compile(loss = 'categorical_crossentropy', optimizer='adam',metrics = ['accuracy'])
    
    train_and_save(padded, labels, model, 32, num_epochs, val)

# %%
# Out:
# Help on TrainAndSave in module core.ukraine_utilities object:
#
# class TrainAndSave(builtins.object)
#  |  TrainAndSave(X_train, y_train, vocab_size, embedding_size, max_words)
#  |
#  |  class for training a model, and then exporting a JSON object and plotting
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, X_train, y_train, vocab_size, embedding_size, max_words)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  save(self, model, num_epochs, val, plots_dir, models_dir)
#  |      train the model, generate JSON and plots, and save in respective locations
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
saver.save(model, 10, 0.2, plots_dir, models_dir)
# Out:
# Epoch 1/10
# 166/166 [==============================] - 9s 53ms/step - loss: 0.0894 - accuracy: 0.9568 - val_loss: 1.1482 - val_accuracy: 0.6989
# Epoch 2/10
# 166/166 [==============================] - 8s 51ms/step - loss: 0.0860 - accuracy: 0.9572 - val_loss: 1.1670 - val_accuracy: 0.7011
# Epoch 3/10
# 166/166 [==============================] - 8s 51ms/step - loss: 0.0845 - accuracy: 0.9579 - val_loss: 1.1912 - val_accuracy: 0.6936
# Epoch 4/10
# 166/166 [==============================] - 9s 51ms/step - loss: 0.0826 - accuracy: 0.9581 - val_loss: 1.1833 - val_accuracy: 0.6913
# Epoch 5/10
# 166/166 [==============================] - 9s 52ms/step - loss: 0.0846 - accuracy: 0.9558 - val_loss: 1.2510 - val_accuracy: 0.6770
# Epoch 6/10
# 166/166 [==============================] - 9s 51ms/step - loss: 0.0794 - accuracy: 0.9589 - val_loss: 1.2156 - val_accuracy: 0.6913
# Epoch 7/10
#  70/166 [===========>..................] - ETA: 5s - loss: 0.0658 - accuracy: 0.9621
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [375], in <cell line: 1>()
# ----> 1 saver.save(model, 10, 0.2, plots_dir, models_dir)
#
# File ~/Documents/UkraineWarSentimentAnalysis/core/ukraine_utilities.py:200, in save(self, model, num_epochs, val, plots_dir, models_dir)
#     198 def save(self, model, num_epochs, val, plots_dir, models_dir):
#     199     """
# --> 200     train the model, generate JSON and plots, and save in respective locations
#     201     """
#     202     self._fit_model(model, num_epochs, val)
#
# File ~/Documents/UkraineWarSentimentAnalysis/core/ukraine_utilities.py:135, in _fit_model(self, model, num_epochs, val)
#     133 FOR INTERNAL USE ONLY
#     134 fit 'model' for 'num_epochs' epochs with 'val' validation split
# --> 135 """
#     136 start = time.time()
#     137 model.fit(self.X_train,
#
# File ~/miniconda3/envs/ukraine/lib/python3.10/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/ukraine/lib/python3.10/site-packages/keras/engine/training.py:1384, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1377 with tf.profiler.experimental.Trace(
#    1378     'train',
#    1379     epoch_num=epoch,
#    1380     step_num=step,
#    1381     batch_size=batch_size,
#    1382     _r=1):
#    1383   callbacks.on_train_batch_begin(step)
# -> 1384   tmp_logs = self.train_function(iterator)
#    1385   if data_handler.should_sync:
#    1386     context.async_wait()
#
# File ~/miniconda3/envs/ukraine/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/ukraine/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniconda3/envs/ukraine/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~/miniconda3/envs/ukraine/lib/python3.10/site-packages/tensorflow/python/eager/function.py:2956, in Function.__call__(self, *args, **kwargs)
#    2953 with self._lock:
#    2954   (graph_function,
#    2955    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2956 return graph_function._call_flat(
#    2957     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/miniconda3/envs/ukraine/lib/python3.10/site-packages/tensorflow/python/eager/function.py:1853, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1849 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1850 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1851     and executing_eagerly):
#    1852   # No tape is watching; skip to running the function.
# -> 1853   return self._build_call_outputs(self._inference_function.call(
#    1854       ctx, args, cancellation_manager=cancellation_manager))
#    1855 forward_backward = self._select_forward_and_backward_functions(
#    1856     args,
#    1857     possible_gradient_type,
#    1858     executing_eagerly)
#    1859 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniconda3/envs/ukraine/lib/python3.10/site-packages/tensorflow/python/eager/function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File ~/miniconda3/envs/ukraine/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:
